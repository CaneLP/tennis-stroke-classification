# %% [markdown]
# Purpose of this notebook is to use relabeled data and update classes where needed (or remove bad examples). Reasons for bad examples in the dataset are bad audio ballhit detection model detections or change of angle on the broadcasting video.

# %%
import os
import pandas as pd

# %%
match_info_json_path = "../../data/sample_files/match_info.json"

dataset_rev = '../../data/sample_files/dataset_info_manual_revision.csv'

# %%
match_info = pd.read_json(match_info_json_path)
match_info.head()
# Out:
#    match_id                                           filename  \
# 0         0  000_Novak_Djokovic_v_Andy_Murray_Australian_Op...
# 1         1  001_Novak_Djokovic_v_Rafael_Nadal_Australian_O...
# 2         2  002_Novak_Djokovic_v_Roger_Federer_US_Open_201...
# 3         3  003_Novak_Djokovic_v_Roger_Federer_Wimbledon_2...
# 4         4  004_Rafael_Nadal_v_Nick_Kyrgios_Wimbledon_2019...
#
#   match_start_top match_start_bottom       fps  first_point_start_frame  \
# 0  Novak Djokovic        Andy Murray  25.00000                    41250
# 1  Novak Djokovic       Rafael Nadal  25.00000                    18000
# 2   Roger Federer     Novak Djokovic  29.97003                      500
# 3   Roger Federer     Novak Djokovic  25.00000                      350
# 4    Rafael Nadal       Nick Kyrgios  25.00000                        0
#
#      surface       tournament  year round
# 0  hardcourt  Australian Open  2016     F
# 1  hardcourt  Australian Open  2012     F
# 2  hardcourt          US Open  2015     F
# 3      grass        Wimbledon  2019     F
# 4      grass        Wimbledon  2019    R2

# %%
rev_df = pd.read_csv(dataset_rev)
rev_df.head()
# Out:
#                                          filename  match_id  match_fps  \
# 0     m000_p000_bh00_serve_top_Novak_Djokovic.mp4         0       25.0
# 1     m000_p000_bh01_serve_top_Novak_Djokovic.mp4         0       25.0
# 2  m000_p000_bh02_forehand_bottom_Andy_Murray.mp4         0       25.0
# 3     m000_p001_bh00_serve_top_Novak_Djokovic.mp4         0       25.0
# 4  m000_p001_bh01_backhand_bottom_Andy_Murray.mp4         0       25.0
#
#    point_id  ballhit_id     timestamp  frame_pos     class new_class_top  \
# 0         0           0  00:27:31.896      41297     serve           NaN
# 1         0           1  00:27:41.370      41534     serve           NaN
# 2         0           2  00:27:42.113      41552  forehand           NaN
# 3         1           0  00:28:02.918      42072     serve           NaN
# 4         1           1  00:28:03.661      42091  backhand           NaN
#
#   new_class_bottom discard/comment DUMMY  \
# 0              NaN             NaN   NaN
# 1              NaN             NaN   NaN
# 2              NaN             NaN   NaN
# 3              NaN             NaN   NaN
# 4              NaN             NaN   NaN
#
#                                   stroke_description          player position  \
# 0                  1st serve down the T, fault (net)  Novak Djokovic      top
# 1                                     2nd serve wide  Novak Djokovic      top
# 2  forehand return crosscourt (long), unforced er...     Andy Murray   bottom
# 3                                     1st serve wide  Novak Djokovic      top
# 4       backhand slice return crosscourt (very deep)     Andy Murray   bottom
#
#          opponent    surface       tournament round  year
# 0     Andy Murray  hardcourt  Australian Open     F  2016
# 1     Andy Murray  hardcourt  Australian Open     F  2016
# 2  Novak Djokovic  hardcourt  Australian Open     F  2016
# 3     Andy Murray  hardcourt  Australian Open     F  2016
# 4  Novak Djokovic  hardcourt  Australian Open     F  2016

# %%
def bad_row(row):
    return (
        row['discard/comment'] in ['angle', 'ballhit'] and
        pd.isna(row['new_class_top']) and pd.isna(row['new_class_bottom'])
    )

# %%
clean_dataset = []

stroke_cls = ['forehand', 'backhand', 'serve', 'other']
stroke_counts = {
    'top': dict.fromkeys(stroke_cls, 0),
    'bottom': dict.fromkeys(stroke_cls, 0)
}

for index, row in rev_df.iterrows():
    if not bad_row(row):
        # determine new stroke type for bottom and for top player
        if pd.isna(row['new_class_top']) and pd.isna(row['new_class_bottom']):  # keep old labels
            top_cls = row['class'] if row['position'] == 'top' else 'other'
            btm_cls = row['class'] if row['position'] == 'bottom' else 'other'
        else:
            top_cls = row['new_class_top']
            btm_cls = row['new_class_bottom']

        stroke_counts['top'][top_cls] += 1
        stroke_counts['bottom'][btm_cls] += 1
            
        # new filename and path
        new_filename = (
            f"t_{top_cls}_{stroke_counts['top'][top_cls]:05d}_"
            f"b_{btm_cls}_{stroke_counts['bottom'][btm_cls]:05d}_"
            f"m{row['match_id']:03d}.mp4"
        )
        
        vid_info = {
            'filename': new_filename,
            'original_filename': row['filename'],
            'top_cls': top_cls,
            'btm_cls': btm_cls,
            'match_id': row['match_id'],
            'fps': match_info.loc[match_info['match_id'] == row['match_id'], 'fps'].values[0],
            'ballhit_match_timestamp': row['timestamp'],
            'ballhit_match_frame_pos': row['frame_pos'],
            'surface':  match_info.loc[match_info['match_id'] == row['match_id'], 'surface'].values[0]
        }

        clean_dataset.append(vid_info)
    else:
        pass
        # print(index)

# %%
clean_dataset_df = pd.DataFrame(clean_dataset)
clean_dataset_df.head()
# Out:
#                                   filename  \
# 0     t_serve_00001_b_other_00001_m000.mp4
# 1     t_serve_00002_b_other_00002_m000.mp4
# 2  t_other_00001_b_forehand_00001_m000.mp4
# 3     t_serve_00003_b_other_00003_m000.mp4
# 4  t_other_00002_b_backhand_00001_m000.mp4
#
#                                 original_filename top_cls   btm_cls  match_id  \
# 0     m000_p000_bh00_serve_top_Novak_Djokovic.mp4   serve     other         0
# 1     m000_p000_bh01_serve_top_Novak_Djokovic.mp4   serve     other         0
# 2  m000_p000_bh02_forehand_bottom_Andy_Murray.mp4   other  forehand         0
# 3     m000_p001_bh00_serve_top_Novak_Djokovic.mp4   serve     other         0
# 4  m000_p001_bh01_backhand_bottom_Andy_Murray.mp4   other  backhand         0
#
#     fps ballhit_match_timestamp  ballhit_match_frame_pos    surface
# 0  25.0            00:27:31.896                    41297  hardcourt
# 1  25.0            00:27:41.370                    41534  hardcourt
# 2  25.0            00:27:42.113                    41552  hardcourt
# 3  25.0            00:28:02.918                    42072  hardcourt
# 4  25.0            00:28:03.661                    42091  hardcourt

# %%
output_folder = "temp"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
clean_dataset_df.to_csv('temp/clean_dataset_info.csv', index=False)

# %%
test_df = pd.read_csv('temp/clean_dataset_info.csv')
test_df[7500:7505]
# Out:
#                                      filename  \
# 7500  t_other_03857_b_forehand_01438_m105.mp4
# 7501  t_backhand_01254_b_other_03859_m105.mp4
# 7502     t_serve_00947_b_other_03860_m105.mp4
# 7503  t_other_03858_b_backhand_01193_m105.mp4
# 7504  t_forehand_01446_b_other_03861_m105.mp4
#
#                                       original_filename   top_cls   btm_cls  \
# 7500  m105_p211_bh09_forehand_bottom_Novak_Djokovic.mp4     other  forehand
# 7501  m105_p211_bh10_forehand_top_Stefanos_Tsitsipas...  backhand     other
# 7502    m105_p215_bh00_serve_top_Stefanos_Tsitsipas.mp4     serve     other
# 7503  m105_p215_bh01_backhand_bottom_Novak_Djokovic.mp4     other  backhand
# 7504  m105_p215_bh02_forehand_top_Stefanos_Tsitsipas...  forehand     other
#
#       match_id        fps ballhit_match_timestamp  ballhit_match_frame_pos  \
# 7500       105  25.000066            02:47:38.449                   251461
# 7501       105  25.000066            02:47:39.935                   251499
# 7502       105  25.000066            02:50:12.629                   255316
# 7503       105  25.000066            02:50:13.558                   255339
# 7504       105  25.000066            02:50:15.787                   255395
#
#      surface
# 7500    clay
# 7501    clay
# 7502    clay
# 7503    clay
# 7504    clay
