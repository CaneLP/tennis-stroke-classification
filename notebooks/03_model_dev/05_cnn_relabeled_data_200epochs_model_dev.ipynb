# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix

import os
import shutil
from PIL import Image
import numpy as np
import seaborn as sns
import time

# %% [markdown]
# # Util funcs

# %% [markdown]
# Podaci su prečišćeni korišćenjem funkcije `handle_invalid_action_images(dataset)` dostupnoj i korišćenoj u svesci `../02_dataset_creation/07_handle_invalid_action_images.ipynb`, tako da u nastavku nisu neophodne dodatne provere u vezi formata slika, i sl.

# %%
def print_time_taken(start_time, end_time):
    elapsed_time = end_time - start_time
    hours, rem = divmod(elapsed_time, 3600)
    minutes, seconds = divmod(rem, 60)
    print(f"Time taken: {int(hours):02}:{int(minutes):02}:{seconds:05.2f}")

# %% [markdown]
# # CNN

# %%
class TennisStrokeCNNClassifier(nn.Module):
    def __init__(self, num_classes=4):
        
        super(TennisStrokeCNNClassifier, self).__init__()
        self.num_classes = num_classes
        
        self.pad = nn.ReplicationPad2d(1)
        
        self.conv1 = nn.Conv2d(3, 6, 3)
        self.bn1 = nn.BatchNorm2d(6)
        
        self.conv2 = nn.Conv2d(6, 16, 3)
        self.bn2 = nn.BatchNorm2d(16)
        self.pool = nn.MaxPool2d(2, 2)
        
        self.conv3 = nn.Conv2d(16, 32, 3)
        self.bn3 = nn.BatchNorm2d(32)
        
        self.fc1 = nn.Linear(32 * 7 * 3, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, num_classes)
        
        self.dropout = nn.Dropout(p=0.6)
        self.relu = nn.ReLU()
                
        
    def _num_flatten_features(self, x):
        num_features = 1
        for s in x.size()[1:]:  # Don't use batch size dim
            num_features *= s
        return num_features    
    
    
    def forward(self, x):
        x = self.pad(x)
        x = self.relu(self.bn1(self.conv1(x)))
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.dropout(x)
        x = self.relu(self.bn3(self.conv3(x)))
        
        x = x.view(-1, self._num_flatten_features(x))
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        
        return x

# %%
def compute_dataset_stats(dataset_path, batch_size=64):
    dataset = datasets.ImageFolder(root=dataset_path, transform=transforms.ToTensor())
    
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=4)
    
    mean = torch.zeros(3)
    std = torch.zeros(3)
    n_samples = 0
    
    for images, _ in loader:
        batch_samples = images.size(0)
        images = images.view(batch_samples, images.size(1), -1)
        mean += images.mean(2).sum(0)
        std += images.std(2).sum(0)
        n_samples += batch_samples
    
    mean /= n_samples
    std /= n_samples
    
    mean = mean.tolist()
    std = std.tolist()
    
    return mean, std

def set_random_state(seed):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

def train_net(num_epochs, dataset_path, num_classes=4, batch_size=32, lr=0.001,
              val_size=0.2, test_size=0.1, random_state=42, patience=3, factor=0.5):
    
    set_random_state(42)
    
    print('Calculating mean and std for normalization...')
    mean, std = compute_dataset_stats(dataset_path)
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=mean, std=std),
    ])
    
    full_dataset = datasets.ImageFolder(root=dataset_path, transform=transform)
    class_names = full_dataset.classes
    
    dataset_size = len(full_dataset)
    indices = list(range(dataset_size))
    
    # Dataset loading consisent with the rest of the project, using the same random_state and split sizes
    train_val_indices, test_indices = train_test_split(indices, test_size=test_size, stratify=full_dataset.targets, random_state=random_state)
    train_indices, val_indices = train_test_split(train_val_indices, test_size=val_size / (1 - test_size),
                                                  stratify=np.array(full_dataset.targets)[train_val_indices], 
                                                  random_state=random_state)
    
    train_set = torch.utils.data.Subset(full_dataset, train_indices)
    val_set = torch.utils.data.Subset(full_dataset, val_indices)
    test_set = torch.utils.data.Subset(full_dataset, test_indices)

    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=8)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=True, num_workers=8)
    test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=True, num_workers=8)
    
    model = TennisStrokeCNNClassifier(num_classes)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    # update lr when the conditions are met
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', 
                                                           factor=factor, patience=patience)

    # track all these changes during training
    train_accs, val_accs, train_losses, val_losses = [], [], [], []
    train_recalls, val_recalls, train_f1s, val_f1s = [], [], [], []
    learning_rates = []
    
    print('Training process initialized.')
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        all_preds_train = []
        all_labels_train = []
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            # zero the parameter gradients!
            optimizer.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            _, preds = torch.max(outputs, 1)
            all_preds_train.extend(preds.cpu().numpy())
            all_labels_train.extend(labels.cpu().numpy())
            
        train_loss = running_loss / len(train_loader)
        train_acc = accuracy_score(all_labels_train, all_preds_train)
        train_recall = recall_score(all_labels_train, all_preds_train, average='macro')
        train_f1 = f1_score(all_labels_train, all_preds_train, average='macro')
        
        train_losses.append(train_loss)
        train_accs.append(train_acc)
        train_recalls.append(train_recall)
        train_f1s.append(train_f1)
        
        model.eval()
        running_val_loss = 0.0
        all_preds_val = []
        all_labels_val = []
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                
                running_val_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                all_preds_val.extend(preds.cpu().numpy())
                all_labels_val.extend(labels.cpu().numpy())
        
        val_loss = running_val_loss / len(val_loader)
        val_acc = accuracy_score(all_labels_val, all_preds_val)
        val_recall = recall_score(all_labels_val, all_preds_val, average='macro')
        val_f1 = f1_score(all_labels_val, all_preds_val, average='macro')
        
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        val_recalls.append(val_recall)
        val_f1s.append(val_f1)

        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]['lr']
        learning_rates.append(scheduler.get_last_lr())
        
        print('-'*50)
        print(f'Epoch {epoch+1}/{num_epochs}')
        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, '
              f'Train Recall: {train_recall:.4f}, Train F1: {train_f1:.4f}')
        print(f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}, '
              f'Val Recall: {val_recall:.4f}, Val F1: {val_f1:.4f}')
        print(f'Learning Rate: {current_lr:.2e}')
        
    print('Finished training!')
    
    plt.figure(figsize=(15, 12))
    
    plt.subplot(3, 2, 1)
    plt.plot(range(1, num_epochs+1), train_losses, label="Train Loss")
    plt.plot(range(1, num_epochs+1), val_losses, label="Val Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(3, 2, 2)
    plt.plot(range(1, num_epochs+1), train_accs, label="Train Acc")
    plt.plot(range(1, num_epochs+1), val_accs, label="Val Acc")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(3, 2, 3)
    plt.plot(range(1, num_epochs+1), train_recalls, label="Train Recall")
    plt.plot(range(1, num_epochs+1), val_recalls, label="Val Recall")
    plt.xlabel("Epochs")
    plt.ylabel("Recall")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(3, 2, 4)
    plt.plot(range(1, num_epochs+1), train_f1s, label="Train F1")
    plt.plot(range(1, num_epochs+1), val_f1s, label="Val F1")
    plt.xlabel("Epochs")
    plt.ylabel("F1 Score")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(3, 2, 5)
    plt.plot(range(1, num_epochs+1), learning_rates, label="Learning Rate")
    plt.xlabel("Epochs")
    plt.ylabel("Learning Rate")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

    loaders = {
        'train': train_loader,
        'val': val_loader,
        'test': test_loader
    }
    
    return model, loaders, class_names

# %% [markdown]
# **Na dnu sveske je odrađena analiza za testni skup podataka.**
#
# *Iako je malo duža sveska zbog 200 epoha, ostavljeno je u celosti da bi mogao lepo da se isprati tok treniranja.*

# %%
start = time.time()

dataset_path = '/app/tennis_data/stroke_recognition_dataset/master/v1.0/action_images_dataset_v1.0/bottom'

num_epochs = 200
num_classes = 4
batch_size = 32
learning_rate = 0.001
val_size = 0.2
test_size = 0.1
seed = 42

model, loaders, class_names = train_net(
    num_epochs=num_epochs, 
    dataset_path=dataset_path, 
    num_classes=num_classes, 
    batch_size=batch_size, 
    lr=learning_rate,
    val_size=val_size,
    test_size=test_size,
    random_state=seed
)

end = time.time()
print_time_taken(start, end)
# Out:
# Calculating mean and std for normalization...
# /root/.local/share/virtualenvs/app-4PlAip0Q/lib/python3.8/site-packages/torch/cuda/__init__.py:128: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11020). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Training process initialized.
# --------------------------------------------------
# Epoch 1/200
# Train Loss: 0.8769, Train Acc: 0.6276, Train Recall: 0.4722, Train F1: 0.4927
# Val Loss: 0.6075, Val Acc: 0.7640, Val Recall: 0.6778, Val F1: 0.6888
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 2/200
# Train Loss: 0.6460, Train Acc: 0.7476, Train Recall: 0.6683, Train F1: 0.6743
# Val Loss: 0.4724, Val Acc: 0.8219, Val Recall: 0.7594, Val F1: 0.7682
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 3/200
# Train Loss: 0.5296, Train Acc: 0.8031, Train Recall: 0.7435, Train F1: 0.7487
# Val Loss: 0.3279, Val Acc: 0.8722, Val Recall: 0.8314, Val F1: 0.8352
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 4/200
# Train Loss: 0.4210, Train Acc: 0.8473, Train Recall: 0.8033, Train F1: 0.8071
# Val Loss: 0.2709, Val Acc: 0.8965, Val Recall: 0.8733, Val F1: 0.8670
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 5/200
# Train Loss: 0.3775, Train Acc: 0.8603, Train Recall: 0.8216, Train F1: 0.8231
# Val Loss: 0.2640, Val Acc: 0.8969, Val Recall: 0.8614, Val F1: 0.8699
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 6/200
# Train Loss: 0.3317, Train Acc: 0.8821, Train Recall: 0.8501, Train F1: 0.8519
# Val Loss: 0.2162, Val Acc: 0.9195, Val Recall: 0.9049, Val F1: 0.8973
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 7/200
# Train Loss: 0.3147, Train Acc: 0.8909, Train Recall: 0.8602, Train F1: 0.8618
# Val Loss: 0.2030, Val Acc: 0.9241, Val Recall: 0.8962, Val F1: 0.9014
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 8/200
# Train Loss: 0.2967, Train Acc: 0.8941, Train Recall: 0.8619, Train F1: 0.8662
# Val Loss: 0.1836, Val Acc: 0.9292, Val Recall: 0.9137, Val F1: 0.9117
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 9/200
# Train Loss: 0.2673, Train Acc: 0.9046, Train Recall: 0.8764, Train F1: 0.8780
# Val Loss: 0.2043, Val Acc: 0.9250, Val Recall: 0.9097, Val F1: 0.9069
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 10/200
# Train Loss: 0.2636, Train Acc: 0.9064, Train Recall: 0.8793, Train F1: 0.8816
# Val Loss: 0.1698, Val Acc: 0.9401, Val Recall: 0.9271, Val F1: 0.9241
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 11/200
# Train Loss: 0.2495, Train Acc: 0.9131, Train Recall: 0.8880, Train F1: 0.8907
# Val Loss: 0.1604, Val Acc: 0.9472, Val Recall: 0.9353, Val F1: 0.9347
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 12/200
# Train Loss: 0.2356, Train Acc: 0.9213, Train Recall: 0.8980, Train F1: 0.9002
# Val Loss: 0.1564, Val Acc: 0.9468, Val Recall: 0.9339, Val F1: 0.9333
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch
Val Acc: 0.9702, Val Recall: 0.9630, Val F1: 0.9645
# Learning Rate: 7.81e-06
# --------------------------------------------------
# Epoch 83/200
# Train Loss: 0.0835, Train Acc: 0.9716, Train Recall: 0.9643, Train F1: 0.9651
# Val Loss: 0.0927, Val Acc: 0.9707, Val Recall: 0.9636, Val F1: 0.9654
# Learning Rate: 3.91e-06
# --------------------------------------------------
# Epoch 84/200
# Train Loss: 0.0845, Train Acc: 0.9713, Train Recall: 0.9638, Train F1: 0.9647
# Val Loss: 0.0936, Val Acc: 0.9694, Val Recall: 0.9618, Val F1: 0.9633
# Learning Rate: 3.91e-06
# --------------------------------------------------
# Epoch 85/200
# Train Loss: 0.0795, Train Acc: 0.9729, Train Recall: 0.9653, Train F1: 0.9666
# Val Loss: 0.0922, Val Acc: 0.9707, Val Recall: 0.9636, Val F1: 0.9652
# Learning Rate: 3.91e-06
# --------------------------------------------------
# Epoch 86/200
# Train Loss: 0.0830, Train Acc: 0.9743, Train Recall: 0.9670, Train F1: 0.9677
# Val Loss: 0.0937, Val Acc: 0.9698, Val Recall: 0.9629, Val F1: 0.9643
# Learning Rate: 3.91e-06
# --------------------------------------------------
# Epoch 87/200
# Train Loss: 0.0882, Train Acc: 0.9727, Train Recall: 0.9652, Train F1: 0.9663
# Val Loss: 0.0923, Val Acc: 0.9702, Val Recall: 0.9632, Val F1: 0.9648
# Learning Rate: 3.91e-06
# --------------------------------------------------
# Epoch 88/200
# Train Loss: 0.0790, Train Acc: 0.9734, Train Recall: 0.9677, Train F1: 0.9684
# Val Loss: 0.0926, Val Acc: 0.9719, Val Recall: 0.9656, Val F1: 0.9671
# Learning Rate: 3.91e-06
# --------------------------------------------------
# Epoch 89/200
# Train Loss: 0.0847, Train Acc: 0.9734, Train Recall: 0.9668, Train F1: 0.9672
# Val Loss: 0.0924, Val Acc: 0.9707, Val Recall: 0.9636, Val F1: 0.9652
# Learning Rate: 1.95e-06
# --------------------------------------------------
# Epoch 90/200
# Train Loss: 0.0792, Train Acc: 0.9740, Train Recall: 0.9669, Train F1: 0.9686
# Val Loss: 0.0926, Val Acc: 0.9707, Val Recall: 0.9639, Val F1: 0.9654
# Learning Rate: 1.95e-06
# --------------------------------------------------
# Epoch 91/200
# Train Loss: 0.0836, Train Acc: 0.9726, Train Recall: 0.9660, Train F1: 0.9666
# Val Loss: 0.0930, Val Acc: 0.9698, Val Recall: 0.9624, Val F1: 0.9639
# Learning Rate: 1.95e-06
# --------------------------------------------------
# Epoch 92/200
# Train Loss: 0.0811, Train Acc: 0.9741, Train Recall: 0.9667, Train F1: 0.9680
# Val Loss: 0.0926, Val Acc: 0.9711, Val Recall: 0.9638, Val F1: 0.9656
# Learning Rate: 1.95e-06
# --------------------------------------------------
# Epoch 93/200
# Train Loss: 0.0799, Train Acc: 0.9745, Train Recall: 0.9678, Train F1: 0.9681
# Val Loss: 0.0932, Val Acc: 0.9702, Val Recall: 0.9630, Val F1: 0.
# --------------------------------------------------
# Epoch 108/200
# Train Loss: 0.0807, Train Acc: 0.9734, Train Recall: 0.9664, Train F1: 0.9673
# Val Loss: 0.0944, Val Acc: 0.9707, Val Recall: 0.9635, Val F1: 0.9651
# Learning Rate: 1.22e-07
# --------------------------------------------------
# Epoch 109/200
# Train Loss: 0.0799, Train Acc: 0.9740, Train Recall: 0.9666, Train F1: 0.9681
# Val Loss: 0.0930, Val Acc: 0.9702, Val Recall: 0.9626, Val F1: 0.9643
# Learning Rate: 6.10e-08
# --------------------------------------------------
# Epoch 110/200
# Train Loss: 0.0828, Train Acc: 0.9739, Train Recall: 0.9676, Train F1: 0.9677
# Val Loss: 0.0929, Val Acc: 0.9707, Val Recall: 0.9636, Val F1: 0.9656
# Learning Rate: 6.10e-08
# --------------------------------------------------
# Epoch 111/200
# Train Loss: 0.0863, Train Acc: 0.9720, Train Recall: 0.9642, Train F1: 0.9651
# Val Loss: 0.0929, Val Acc: 0.9698, Val Recall: 0.9624, Val F1: 0.9639
# Learning Rate: 6.10e-08
# --------------------------------------------------
# Epoch 112/200
# Train Loss: 0.0853, Train Acc: 0.9744, Train Recall: 0.9677, Train F1: 0.9687
# Val Loss: 0.0929, Val Acc: 0.9698, Val Recall: 0.9626, Val F1: 0.9639
# Learning Rate: 6.10e-08
# --------------------------------------------------
# Epoch 113/200
# Train Loss: 0.0842, Train Acc: 0.9704, Train Recall: 0.9637, Train F1: 0.9642
# Val Loss: 0.0950, Val Acc: 0.9707, Val Recall: 0.9633, Val F1: 0.9652
# Learning Rate: 3.05e-08
# --------------------------------------------------
# Epoch 114/200
# Train Loss: 0.0870, Train Acc: 0.9711, Train Recall: 0.9633, Train F1: 0.9638
# Val Loss: 0.0931, Val Acc: 0.9698, Val Recall: 0.9624, Val F1: 0.9641
# Learning Rate: 3.05e-08
# --------------------------------------------------
# Epoch 115/200
# Train Loss: 0.0831, Train Acc: 0.9743, Train Recall: 0.9676, Train F1: 0.9679
# Val Loss: 0.0941, Val Acc: 0.9702, Val Recall: 0.9633, Val F1: 0.9647
# Learning Rate: 3.05e-08
# --------------------------------------------------
# Epoch 116/200
# Train Loss: 0.0808, Train Acc: 0.9741, Train Recall: 0.9677, Train F1: 0.9684
# Val Loss: 0.0933, Val Acc: 0.9707, Val Recall: 0.9636, Val F1: 0.9653
# Learning Rate: 3.05e-08
# --------------------------------------------------
# Epoch 117/200
# Train Loss: 0.0858, Train Acc: 0.9719, Train Recall: 0.9650, Train F1: 0.9657
# Val Loss: 0.0930, Val Acc: 0.9707, Val Recall: 0.9639, Val F1: 0.9654
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch 118/200
# Train Loss: 0.0837, Train Acc: 0.9750, Train Recall: 0.9681, Train F1: 0.9692
# Val Loss: 0.0933, Val Acc: 0.9702, Val Recall: 0.9628, Val F1: 0.9644
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch 119/200
# Train Loss: 0.0849, Train Acc: 0.9720, Train Recall: 0.9638, Train F1: 0.9648
# Val Loss: 0.0929, Val Acc: 0.9698, Val Recall: 0.9623, Val F1: 0.9642
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch 120/200
# Train Loss: 0.0843, Train Acc: 0.9747, Train Recall: 0.9682, Train F1: 0.9682
# Val Loss: 0.0931, Val Acc: 0.9698, Val Recall: 0.9624, Val F1: 0.9640
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch 121/200
# Train Loss: 0.0846, Train Acc: 0.9737, Train Recall: 0.9670, Train F1: 0.9679
# Val Loss: 0.0928, Val Acc: 0.9698, Val Recall: 0.9624, Val F1: 0.9639
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch 122/200
# Train Loss: 0.0865, Train Acc: 0.9723, Train Recall: 0.9650, Train F1: 0.9657
# Val Loss: 0.0932, Val Acc: 0.9702, Val Recall: 0.9633, Val F1: 0.9647
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch 194/200
# Train Loss: 0.0811, Train Acc: 0.9738, Train Recall: 0.9673, Train F1: 0.9680
# Val Loss: 0.0924, Val Acc: 0.9698, Val Recall: 0.9624, Val F1: 0.9639
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch 195/200
# Train Loss: 0.0812, Train Acc: 0.9757, Train Recall: 0.9685, Train F1: 0.9702
# Val Loss: 0.0920, Val Acc: 0.9711, Val Recall: 0.9643, Val F1: 0.9658
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch 196/200
# Train Loss: 0.0779, Train Acc: 0.9765, Train Recall: 0.9711, Train F1: 0.9713
# Val Loss: 0.0935, Val Acc: 0.9694, Val Recall: 0.9618, Val F1: 0.9633
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch 197/200
# Train Loss: 0.0801, Train Acc: 0.9747, Train Recall: 0.9679, Train F1: 0.9686
# Val Loss: 0.0927, Val Acc: 0.9702, Val Recall: 0.9630, Val F1: 0.9645
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch 198/200
# Train Loss: 0.0821, Train Acc: 0.9746, Train Recall: 0.9683, Train F1: 0.9687
# Val Loss: 0.0920, Val Acc: 0.9707, Val Recall: 0.9634, Val F1: 0.9652
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch 199/200
# Train Loss: 0.0829, Train Acc: 0.9731, Train Recall: 0.9656, Train F1: 0.9664
# Val Loss: 0.0926, Val Acc: 0.9694, Val Recall: 0.9619, Val F1: 0.9635
# Learning Rate: 1.53e-08
# --------------------------------------------------
# Epoch 200/200
# Train Loss: 0.0858, Train Acc: 0.9722, Train Recall: 0.9645, Train F1: 0.9659
# Val Loss: 0.0939, Val Acc: 0.9707, Val Recall: 0.9639, Val F1: 0.9653
# Learning Rate: 1.53e-08
# Finished training!
# Time taken: 00:09:23.53

# %% [markdown]
# # Pokretanje na test skupu i komentar

# %% [markdown]
# **Kao i u prethodnoj svesci gde je treniran CNN na "lošim" podacima, a i u onoj gde je trenirano 50 epoha, možemo primetiti da za razliku od ostalih modela CNN daje ozbiljno dobre rezultate na test skupu ako gledamo njihovu sličnost sa rezultatima na trening, odnosno validacionom skupu. Vrednosti posmatranih metrika su maltene identične. Ovo smo se i nadali da ćemo postići, tj. da će se CNN-ovi pokazati kao dobri generalizatori.**

# %%
model.eval()

all_preds_test = []
all_labels_test = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
with torch.no_grad():
    for inputs, labels in loaders['test']:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds_test.extend(preds.cpu().numpy())
        all_labels_test.extend(labels.cpu().numpy())

test_acc = accuracy_score(all_labels_test, all_preds_test)
test_recall = recall_score(all_labels_test, all_preds_test, average='macro')
test_f1 = f1_score(all_labels_test, all_preds_test, average='macro')

print(f"Test accuracy: {test_acc:.4f}")
print(f"Test recall: {test_recall:.4f}")
print(f"Test F1 score: {test_f1:.4f}")


print("\nClassification report:")
print(classification_report(all_labels_test, all_preds_test, target_names=class_names))

cm = confusion_matrix(all_labels_test, all_preds_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Test accuracy: 0.9673
# Test recall: 0.9653
# Test F1 score: 0.9620
#
# Classification report:
#               precision    recall  f1-score   support
#
#     backhand       0.94      0.93      0.93       190
#     forehand       0.92      0.96      0.94       230
#        other       0.99      0.97      0.98       615
#        serve       0.98      1.00      0.99       159
#
#     accuracy                           0.97      1194
#    macro avg       0.96      0.97      0.96      1194
# weighted avg       0.97      0.97      0.97      1194
