# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix

import os
import shutil
from PIL import Image
import numpy as np
import seaborn as sns
import time

# %% [markdown]
# # Util funcs

# %% [markdown]
# Podaci su prečišćeni korišćenjem funkcije `handle_invalid_action_images(dataset)` dostupnoj i korišćenoj u svesci `../02_dataset_creation/07_handle_invalid_action_images.ipynb`, tako da u nastavku nisu neophodne dodatne provere u vezi formata slika, i sl.

# %%
def print_time_taken(start_time, end_time):
    elapsed_time = end_time - start_time
    hours, rem = divmod(elapsed_time, 3600)
    minutes, seconds = divmod(rem, 60)
    print(f"Time taken: {int(hours):02}:{int(minutes):02}:{seconds:05.2f}")

# %% [markdown]
# # CNN

# %%
class TennisStrokeCNNClassifier(nn.Module):
    def __init__(self, num_classes=4):
        
        super(TennisStrokeCNNClassifier, self).__init__()
        
        self.num_classes = num_classes
        
        self.pad1 = nn.ReplicationPad2d(1)
        
        negative_slope = 0.01
        
        self.conv1 = nn.Conv2d(3, 6, 3)
        self.bn1 = nn.BatchNorm2d(6)
        self.relu1 = nn.LeakyReLU(negative_slope)
        self.dropout1 = nn.Dropout(p=0.5)
        
        self.conv2 = nn.Conv2d(6, 16, 3)
        self.bn2 = nn.BatchNorm2d(16)
        self.relu2 = nn.LeakyReLU(negative_slope)
        
        self.conv3 = nn.Conv2d(16, 32, 3, padding=1)
        self.bn3 = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(2, 2)
        self.relu3 = nn.LeakyReLU(negative_slope)
        self.dropout2 = nn.Dropout(p=0.6)
        
        self.conv4 = nn.Conv2d(32, 64, 3, padding=1)
        self.bn4 = nn.BatchNorm2d(64)
        self.relu4 = nn.LeakyReLU(negative_slope)

        self.conv5 = nn.Conv2d(64, 128, 3)
        self.bn5 = nn.BatchNorm2d(128)
        self.pool2 = nn.MaxPool2d(3, 3)
        self.relu5 = nn.LeakyReLU(negative_slope)

        self.fc1 = nn.Linear(256, 256)
        self.relu6 = nn.LeakyReLU(negative_slope)
        self.dropout3 = nn.Dropout(p=0.2)
        self.fc2 = nn.Linear(256, 128)
        self.relu7 = nn.LeakyReLU(negative_slope)
        self.dropout4 = nn.Dropout(p=0.25)
        self.fc3 = nn.Linear(128, 64)
        self.relu8 = nn.LeakyReLU(negative_slope)
        self.fc4 = nn.Linear(64, num_classes)
            
        
    def _num_flatten_features(self, x):
        num_features = 1
        for s in x.size()[1:]:  # Dont' use batch size dim
            num_features *= s
        return num_features    
    
        
    def forward(self, x):
        x = self.pad1(x)
        # print(x.shape)
        x = self.relu1(self.bn1(self.conv1(x)))
        x = self.dropout1(x)

        x = self.relu2(self.bn2(self.conv2(x)))
        
        x = self.bn3(self.conv3(x))
        x = self.pool1(x)
        x = self.relu3(x)
        x = self.dropout2(x)
        
        x = self.relu4(self.bn4(self.conv4(x)))
        
        x = self.pool2(self.bn5(self.conv5(x)))
        x = self.relu5(x)
        
        # print(x.shape)
        
        x = x.view(-1, self._num_flatten_features(x))
        x = self.relu6(self.fc1(x))
        x = self.dropout3(x)
        
        x = self.relu7(self.fc2(x))
        x = self.dropout4(x)
        
        x = self.relu8(self.fc3(x))
        x = self.fc4(x)
        
        x = F.log_softmax(x, dim=1)

        return x

# %%
def compute_dataset_stats(dataset_path, batch_size=64, random_state=42):
    full_dataset = datasets.ImageFolder(root=dataset_path, transform=transforms.ToTensor())    
    class_names = full_dataset.classes
    
    dataset_size = len(full_dataset)
    indices = list(range(dataset_size))
    
    # Dataset loading consisent with the rest of the project, using the same random_state and split sizes
    train_val_indices, test_indices = train_test_split(indices, test_size=test_size, stratify=full_dataset.targets, random_state=random_state)
    train_indices, val_indices = train_test_split(train_val_indices, test_size=val_size / (1 - test_size),
                                                  stratify=np.array(full_dataset.targets)[train_val_indices], 
                                                  random_state=random_state)
    
    train_set = Subset(full_dataset, train_indices)
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=8)
    
    mean = torch.zeros(3)
    std = torch.zeros(3)
    n_samples = 0
    
    for images, _ in train_loader:
        batch_samples = images.size(0)
        images = images.view(batch_samples, images.size(1), -1)
        mean += images.mean(2).sum(0)
        std += images.std(2).sum(0)
        n_samples += batch_samples
    
    mean /= n_samples
    std /= n_samples
    
    mean = mean.tolist()
    std = std.tolist()
    
    return mean, std

def set_random_state(seed):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

def train_net(num_epochs, dataset_path, num_classes=4, batch_size=32, lr=0.001,
              val_size=0.2, test_size=0.1, random_state=42, patience=3, factor=0.3):
    
    set_random_state(random_state)
    
    print('Calculating mean and std for normalization...')
    mean, std = compute_dataset_stats(dataset_path)
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=mean, std=std),
    ])
    
    full_dataset = datasets.ImageFolder(root=dataset_path, transform=transform)
    class_names = full_dataset.classes
    
    dataset_size = len(full_dataset)
    indices = list(range(dataset_size))
    
    # Dataset loading consisent with the rest of the project, using the same random_state and split sizes
    train_val_indices, test_indices = train_test_split(indices, test_size=test_size, stratify=full_dataset.targets, random_state=random_state)
    train_indices, val_indices = train_test_split(train_val_indices, test_size=val_size / (1 - test_size),
                                                  stratify=np.array(full_dataset.targets)[train_val_indices], 
                                                  random_state=random_state)
    
    train_set = Subset(full_dataset, train_indices)
    val_set = Subset(full_dataset, val_indices)
    test_set = Subset(full_dataset, test_indices)

    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=8)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=True, num_workers=8)
    test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=True, num_workers=8)
    
    model = TennisStrokeCNNClassifier(num_classes)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    # update lr when the conditions are met
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', 
                                                           factor=factor, patience=patience)

    # track all these changes during training
    train_accs, val_accs, train_losses, val_losses = [], [], [], []
    train_recalls, val_recalls, train_f1s, val_f1s = [], [], [], []
    learning_rates = []
    
    print('Training process initialized.')
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        all_preds_train = []
        all_labels_train = []
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            # zero the parameter gradients!
            optimizer.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            _, preds = torch.max(outputs, 1)
            all_preds_train.extend(preds.cpu().numpy())
            all_labels_train.extend(labels.cpu().numpy())
            
        train_loss = running_loss / len(train_loader)
        train_acc = accuracy_score(all_labels_train, all_preds_train)
        train_recall = recall_score(all_labels_train, all_preds_train, average='macro')
        train_f1 = f1_score(all_labels_train, all_preds_train, average='macro')
        
        train_losses.append(train_loss)
        train_accs.append(train_acc)
        train_recalls.append(train_recall)
        train_f1s.append(train_f1)
        
        model.eval()
        running_val_loss = 0.0
        all_preds_val = []
        all_labels_val = []
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                
                running_val_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                all_preds_val.extend(preds.cpu().numpy())
                all_labels_val.extend(labels.cpu().numpy())
        
        val_loss = running_val_loss / len(val_loader)
        val_acc = accuracy_score(all_labels_val, all_preds_val)
        val_recall = recall_score(all_labels_val, all_preds_val, average='macro')
        val_f1 = f1_score(all_labels_val, all_preds_val, average='macro')
        
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        val_recalls.append(val_recall)
        val_f1s.append(val_f1)

        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]['lr']
        learning_rates.append(scheduler.get_last_lr())
        
        print('-'*50)
        print(f'Epoch {epoch+1}/{num_epochs}')
        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, '
              f'Train Recall: {train_recall:.4f}, Train F1: {train_f1:.4f}')
        print(f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}, '
              f'Val Recall: {val_recall:.4f}, Val F1: {val_f1:.4f}')
        print(f'Learning Rate: {current_lr:.2e}')
        
    print('Finished training!')
    
    plt.figure(figsize=(15, 12))
    
    plt.subplot(3, 2, 1)
    plt.plot(range(1, num_epochs+1), train_losses, label="Train Loss")
    plt.plot(range(1, num_epochs+1), val_losses, label="Val Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(3, 2, 2)
    plt.plot(range(1, num_epochs+1), train_accs, label="Train Acc")
    plt.plot(range(1, num_epochs+1), val_accs, label="Val Acc")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(3, 2, 3)
    plt.plot(range(1, num_epochs+1), train_recalls, label="Train Recall")
    plt.plot(range(1, num_epochs+1), val_recalls, label="Val Recall")
    plt.xlabel("Epochs")
    plt.ylabel("Recall")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(3, 2, 4)
    plt.plot(range(1, num_epochs+1), train_f1s, label="Train F1")
    plt.plot(range(1, num_epochs+1), val_f1s, label="Val F1")
    plt.xlabel("Epochs")
    plt.ylabel("F1 Score")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(3, 2, 5)
    plt.plot(range(1, num_epochs+1), learning_rates, label="Learning Rate")
    plt.xlabel("Epochs")
    plt.ylabel("Learning Rate")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

    loaders = {
        'train': train_loader,
        'val': val_loader,
        'test': test_loader
    }
    
    return model, loaders, class_names

# %% [markdown]
# **Na dnu sveske je odrađena analiza za testni skup podataka.**
#
# *Iako je malo duža sveska zbog 200 epoha, ostavljeno je u celosti da bi mogao lepo da se isprati tok treniranja.*

# %%
start = time.time()

dataset_path = '../../data/datasets/action_images_dataset_v1.0'

num_epochs = 100
num_classes = 4
batch_size = 64
learning_rate = 0.01  # starting with higher lr than previously
val_size = 0.2
test_size = 0.1
seed = 42

model, loaders, class_names = train_net(
    num_epochs=num_epochs, 
    dataset_path=dataset_path, 
    num_classes=num_classes, 
    batch_size=batch_size, 
    lr=learning_rate,
    val_size=val_size,
    test_size=test_size,
    random_state=seed
)

end = time.time()
print_time_taken(start, end)
# Out:
# Calculating mean and std for normalization...
# /root/.local/share/virtualenvs/app-4PlAip0Q/lib/python3.8/site-packages/torch/cuda/__init__.py:128: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11020). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Training process initialized.
# --------------------------------------------------
# Epoch 1/100
# Train Loss: 0.9775, Train Acc: 0.5658, Train Recall: 0.3694, Train F1: 0.3621
# Val Loss: 0.8064, Val Acc: 0.6915, Val Recall: 0.6261, Val F1: 0.5384
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 2/100
# Train Loss: 0.6653, Train Acc: 0.7221, Train Recall: 0.6268, Train F1: 0.6248
# Val Loss: 0.4880, Val Acc: 0.8198, Val Recall: 0.7645, Val F1: 0.7634
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 3/100
# Train Loss: 0.5228, Train Acc: 0.7963, Train Recall: 0.7279, Train F1: 0.7287
# Val Loss: 0.3727, Val Acc: 0.8382, Val Recall: 0.7972, Val F1: 0.7819
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 4/100
# Train Loss: 0.4816, Train Acc: 0.8210, Train Recall: 0.7634, Train F1: 0.7638
# Val Loss: 0.3197, Val Acc: 0.8889, Val Recall: 0.8539, Val F1: 0.8553
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 5/100
# Train Loss: 0.4131, Train Acc: 0.8532, Train Recall: 0.8075, Train F1: 0.8110
# Val Loss: 0.3232, Val Acc: 0.8789, Val Recall: 0.8673, Val F1: 0.8530
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 6/100
# Train Loss: 0.3724, Train Acc: 0.8682, Train Recall: 0.8279, Train F1: 0.8272
# Val Loss: 0.3457, Val Acc: 0.8814, Val Recall: 0.8539, Val F1: 0.8595
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 7/100
# Train Loss: 0.3596, Train Acc: 0.8781, Train Recall: 0.8428, Train F1: 0.8439
# Val Loss: 0.2595, Val Acc: 0.9019, Val Recall: 0.8761, Val F1: 0.8676
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 8/100
# Train Loss: 0.3283, Train Acc: 0.8848, Train Recall: 0.8530, Train F1: 0.8552
# Val Loss: 0.2087, Val Acc: 0.9258, Val Recall: 0.9075, Val F1: 0.9010
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 9/100
# Train Loss: 0.2884, Train Acc: 0.9049, Train Recall: 0.8792, Train F1: 0.8804
# Val Loss: 0.2025, Val Acc: 0.9346, Val Recall: 0.9156, Val F1: 0.9160
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 10/100
# Train Loss: 0.2866, Train Acc: 0.9044, Train Recall: 0.8755, Train F1: 0.8785
# Val Loss: 0.3005, Val Acc: 0.9011, Val Recall: 0.8837, Val F1: 0.8710
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 11/100
# Train Loss: 0.2818, Train Acc: 0.9050, Train Recall: 0.8774, Train F1: 0.8797
# Val Loss: 0.2422, Val Acc: 0.9229, Val Recall: 0.8999, Val F1: 0.8950
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 12/100
# Train Loss: 0.2751, Train Acc: 0.9072, Train Recall: 0.8818, Train F1: 0.8840
# Val Loss: 0.1658, Val Acc: 0.9413, Val Recall: 0.9254, Val F1: 0.9293
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 13/100
# Train Loss: 0.2691, Train Acc: 0.9082, Train Recall: 0.8811, Train F1: 0.8859
# Val Loss: 0.1785, Val Acc: 0.9434, Val Recall: 0.9331, Val F1: 0.9309
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 14/100
# Train Loss: 0.2446, Train Acc: 0.9225, Train Recall: 0.9018, Train F1: 0.9035
# Val Loss: 0.1382, Val Acc: 0.9531, Val Recall: 0.9413, Val F1: 0.9417
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 15/100
# Train Loss: 0.2718, Train Acc: 0.9083, Train Recall: 0.8829, Train F1: 0.8865
# Val Loss: 0.1699, Val Acc: 0.9493, Val Recall: 0.9434, Val F1: 0.9390
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 16/100
# Train Loss: 0.2601, Train Acc: 0.9158, Train Recall: 0.8937, Train F1: 0.8945
# Val Loss: 0.2283, Val Acc: 0.9288, Val Recall: 0.9258, Val F1: 0.9134
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 17/100
# Train Loss: 0.2388, Train Acc: 0.9230, Train Recall: 0.9041, Train F1: 0.9054
# Val Loss: 0.1790, Val Acc: 0.9447, Val Recall: 0.9343, Val F1: 0.9288
# Learning Rate: 1.00e-02
# --------------------------------------------------
# Epoch 18/100
# Train Loss: 0.2260, Train Acc: 0.9256, Train Recall: 0.9055, Train F1: 0.9077
# Val Loss: 0.2971, Val Acc: 0.8998, Val Recall: 0.9155, Val F1: 0.8955
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 19/100
# Train Loss: 0.1840, Train Acc: 0.9404, Train Recall: 0.9278, Train F1: 0.9266
# Val Loss: 0.1179, Val Acc: 0.9631, Val Recall: 0.9558, Val F1: 0.9553
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 20/100
# Train Loss: 0.1622, Train Acc: 0.9497, Train Recall: 0.9381, Train F1: 0.9380
# Val Loss: 0.1327, Val Acc: 0.9593, Val Recall: 0.9544, Val F1: 0.9510
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 21/100
# Train Loss: 0.1633, Train Acc: 0.9458, Train Recall: 0.9322, Train F1: 0.9331
# Val Loss: 0.1095, Val Acc: 0.9644, Val Recall: 0.9571, Val F1: 0.9575
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 22/100
# Train Loss: 0.1585, Train Acc: 0.9468, Train Recall: 0.9330, Train F1: 0.9346
# Val Loss: 0.1179, Val Acc: 0.9644, Val Recall: 0.9608, Val F1: 0.9576
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 23/100
# Train Loss: 0.1635, Train Acc: 0.9462, Train Recall: 0.9324, Train F1: 0.9336
# Val Loss: 0.1102, Val Acc: 0.9635, Val Recall: 0.9586, Val F1: 0.9564
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 24/100
# Train Loss: 0.1529, Train Acc: 0.9499, Train Recall: 0.9384, Train F1: 0.9387
# Val Loss: 0.1137, Val Acc: 0.9681, Val Recall: 0.9630, Val F1: 0.9629
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 25/100
# Train Loss: 0.1462, Train Acc: 0.9501, Train Recall: 0.9393, Train F1: 0.9396
# Val Loss: 0.1082, Val Acc: 0.9690, Val Recall: 0.9632, Val F1: 0.9628
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 26/100
# Train Loss: 0.1468, Train Acc: 0.9537, Train Recall: 0.9422, Train F1: 0.9424
# Val Loss: 0.1055, Val Acc: 0.9648, Val Recall: 0.9614, Val F1: 0.9581
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 27/100
# Train Loss: 0.1426, Train Acc: 0.9520, Train Recall: 0.9400, Train F1: 0.9404
# Val Loss: 0.1123, Val Acc: 0.9644, Val Recall: 0.9589, Val F1: 0.9561
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 28/100
# Train Loss: 0.1437, Train Acc: 0.9502, Train Recall: 0.9377, Train F1: 0.9381
# Val Loss: 0.0961, Val Acc: 0.9677, Val Recall: 0.9628, Val F1: 0.9625
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 29/100
# Train Loss: 0.1460, Train Acc: 0.9544, Train Recall: 0.9433, Train F1: 0.9447
# Val Loss: 0.0993, Val Acc: 0.9665, Val Recall: 0.9614, Val F1: 0.9589
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 30/100
# Train Loss: 0.1441, Train Acc: 0.9540, Train Recall: 0.9422, Train F1: 0.9431
# Val Loss: 0.1054, Val Acc: 0.9631, Val Recall: 0.9579, Val F1: 0.9561
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 31/100
# Train Loss: 0.1448, Train Acc: 0.9539, Train Recall: 0.9426, Train F1: 0.9441
# Val Loss: 0.1205, Val Acc: 0.9681, Val Recall: 0.9640, Val F1: 0.9621
# Learning Rate: 3.00e-03
# --------------------------------------------------
# Epoch 32/100
# Train Loss: 0.1326, Train Acc: 0.9567, Train Recall: 0.9463, Train F1: 0.9468
# Val Loss: 0.1203, Val Acc: 0.9652, Val Recall: 0.9617, Val F1: 0.9586
# Learning Rate: 9.00e-04
# --------------------------------------------------
# Epoch 33/100
# Train Loss: 0.1323, Train Acc: 0.9587, Train Recall: 0.9487, Train F1: 0.9492
# Val Loss: 0.0926, Val Acc: 0.9694, Val Recall: 0.9652, Val F1: 0.9646
# Learning Rate: 9.00e-04
# --------------------------------------------------
# Epoch 34/100
# Train Loss: 0.1183, Train Acc: 0.9612, Train Recall: 0.9521, Train F1: 0.9528
# Val Loss: 0.0907, Val Acc: 0.9736, Val Recall: 0.9691, Val F1: 0.9689
# Learning Rate: 9.00e-04
# --------------------------------------------------
# Epoch 35/100
# Train Loss: 0.1118, Train Acc: 0.9646, Train Recall: 0.9556, Train F1: 0.9566
# Val Loss: 0.0883, Val Acc: 0.9732, Val Recall: 0.9691, Val F1: 0.9686
# Learning Rate: 9.00e-04
# --------------------------------------------------
# Epoch 36/100
# Train Loss: 0.1142, Train Acc: 0.9630, Train Recall: 0.9554, Train F1: 0.9554
# Val Loss: 0.0942, Val Acc: 0.9740, Val Recall: 0.9706, Val F1: 0.9692
# Learning Rate: 9.00e-04
# --------------------------------------------------
# Epoch 37/100
# Train Loss: 0.1085, Train Acc: 0.9650, Train Recall: 0.9572, Train F1: 0.9574
# Val Loss: 0.0867, Val Acc: 0.9732, Val Recall: 0.9701, Val F1: 0.9690
# Learning Rate: 9.00e-04
# --------------------------------------------------
# Epoch 38/100
# Train Loss: 0.1030, Train Acc: 0.9687, Train Recall: 0.9611, Train F1: 0.9620
# Val Loss: 0.0833, Val Acc: 0.9736, Val Recall: 0.9701, Val F1: 0.9693
# Learning Rate: 9.00e-04
# --------------------------------------------------
# Epoch 39/100
# Train Loss: 0.1108, Train Acc: 0.9631, Train Recall: 0.9546, Train F1: 0.9556
# Val Loss: 0.0953, Val Acc: 0.9765, Val Recall: 0.9724, Val F1: 0.9726
# Learning Rate: 9.00e-04
# --------------------------------------------------
# Epoch 40/100
# Train Loss: 0.1114, Train Acc: 0.9640, Train Recall: 0.9554, Train F1: 0.9563
# Val Loss: 0.0881, Val Acc: 0.9744, Val Recall: 0.9713, Val F1: 0.9706
# Learning Rate: 9.00e-04
# --------------------------------------------------
# Epoch 41/100
# Train Loss: 0.1003, Train Acc: 0.9677, Train Recall: 0.9595, Train F1: 0.9604
# Val Loss: 0.0887, Val Acc: 0.9702, Val Recall: 0.9653, Val F1: 0.9646
# Learning Rate: 9.00e-04
# --------------------------------------------------
# Epoch 42/100
# Train Loss: 0.1033, Train Acc: 0.9674, Train Recall: 0.9598, Train F1: 0.9606
# Val Loss: 0.0855, Val Acc: 0.9736, Val Recall: 0.9689, Val F1: 0.9685
# Learning Rate: 2.70e-04
# --------------------------------------------------
# Epoch 43/100
# Train Loss: 0.0956, Train Acc: 0.9697, Train Recall: 0.9617, Train F1: 0.9629
# Val Loss: 0.0846, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9697
# Learning Rate: 2.70e-04
# --------------------------------------------------
# Epoch 44/100
# Train Loss: 0.0944, Train Acc: 0.9710, Train Recall: 0.9645, Train F1: 0.9645
# Val Loss: 0.0852, Val Acc: 0.9744, Val Recall: 0.9700, Val F1: 0.9696
# Learning Rate: 2.70e-04
# --------------------------------------------------
# Epoch 45/100
# Train Loss: 0.0920, Train Acc: 0.9715, Train Recall: 0.9652, Train F1: 0.9659
# Val Loss: 0.0890, Val Acc: 0.9740, Val Recall: 0.9706, Val F1: 0.9693
# Learning Rate: 2.70e-04
# --------------------------------------------------
# Epoch 46/100
# Train Loss: 0.0912, Train Acc: 0.9717, Train Recall: 0.9653, Train F1: 0.9658
# Val Loss: 0.0854, Val Acc: 0.9740, Val Recall: 0.9697, Val F1: 0.9695
# Learning Rate: 8.10e-05
# --------------------------------------------------
# Epoch 47/100
# Train Loss: 0.0906, Train Acc: 0.9715, Train Recall: 0.9640, Train F1: 0.9654
# Val Loss: 0.0858, Val Acc: 0.9749, Val Recall: 0.9714, Val F1: 0.9706
# Learning Rate: 8.10e-05
# --------------------------------------------------
# Epoch 48/100
# Train Loss: 0.0966, Train Acc: 0.9697, Train Recall: 0.9626, Train F1: 0.9637
# Val Loss: 0.0853, Val Acc: 0.9749, Val Recall: 0.9719, Val F1: 0.9704
# Learning Rate: 8.10e-05
# --------------------------------------------------
# Epoch 49/100
# Train Loss: 0.0933, Train Acc: 0.9701, Train Recall: 0.9632, Train F1: 0.9635
# Val Loss: 0.0833, Val Acc: 0.9744, Val Recall: 0.9707, Val F1: 0.9700
# Learning Rate: 8.10e-05
# --------------------------------------------------
# Epoch 50/100
# Train Loss: 0.0940, Train Acc: 0.9703, Train Recall: 0.9634, Train F1: 0.9644
# Val Loss: 0.0857, Val Acc: 0.9728, Val Recall: 0.9683, Val F1: 0.9679
# Learning Rate: 2.43e-05
# --------------------------------------------------
# Epoch 51/100
# Train Loss: 0.0848, Train Acc: 0.9723, Train Recall: 0.9653, Train F1: 0.9663
# Val Loss: 0.0866, Val Acc: 0.9744, Val Recall: 0.9707, Val F1: 0.9701
# Learning Rate: 2.43e-05
# --------------------------------------------------
# Epoch 52/100
# Train Loss: 0.0926, Train Acc: 0.9707, Train Recall: 0.9641, Train F1: 0.9644
# Val Loss: 0.0840, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 2.43e-05
# --------------------------------------------------
# Epoch 53/100
# Train Loss: 0.0938, Train Acc: 0.9696, Train Recall: 0.9614, Train F1: 0.9622
# Val Loss: 0.0845, Val Acc: 0.9732, Val Recall: 0.9690, Val F1: 0.9685
# Learning Rate: 2.43e-05
# --------------------------------------------------
# Epoch 54/100
# Train Loss: 0.0894, Train Acc: 0.9749, Train Recall: 0.9684, Train F1: 0.9700
# Val Loss: 0.0862, Val Acc: 0.9736, Val Recall: 0.9696, Val F1: 0.9690
# Learning Rate: 7.29e-06
# --------------------------------------------------
# Epoch 55/100
# Train Loss: 0.0890, Train Acc: 0.9708, Train Recall: 0.9646, Train F1: 0.9653
# Val Loss: 0.0961, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 7.29e-06
# --------------------------------------------------
# Epoch 56/100
# Train Loss: 0.0901, Train Acc: 0.9709, Train Recall: 0.9635, Train F1: 0.9643
# Val Loss: 0.0839, Val Acc: 0.9749, Val Recall: 0.9715, Val F1: 0.9706
# Learning Rate: 7.29e-06
# --------------------------------------------------
# Epoch 57/100
# Train Loss: 0.0940, Train Acc: 0.9719, Train Recall: 0.9654, Train F1: 0.9670
# Val Loss: 0.0835, Val Acc: 0.9749, Val Recall: 0.9710, Val F1: 0.9705
# Learning Rate: 7.29e-06
# --------------------------------------------------
# Epoch 58/100
# Train Loss: 0.0899, Train Acc: 0.9705, Train Recall: 0.9642, Train F1: 0.9643
# Val Loss: 0.0860, Val Acc: 0.9749, Val Recall: 0.9715, Val F1: 0.9706
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 59/100
# Train Loss: 0.0925, Train Acc: 0.9716, Train Recall: 0.9649, Train F1: 0.9657
# Val Loss: 0.0859, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 60/100
# Train Loss: 0.0935, Train Acc: 0.9709, Train Recall: 0.9643, Train F1: 0.9650
# Val Loss: 0.0838, Val Acc: 0.9744, Val Recall: 0.9709, Val F1: 0.9702
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 61/100
# Train Loss: 0.0952, Train Acc: 0.9681, Train Recall: 0.9612, Train F1: 0.9615
# Val Loss: 0.0832, Val Acc: 0.9740, Val Recall: 0.9703, Val F1: 0.9695
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 62/100
# Train Loss: 0.0905, Train Acc: 0.9717, Train Recall: 0.9651, Train F1: 0.9659
# Val Loss: 0.0848, Val Acc: 0.9736, Val Recall: 0.9696, Val F1: 0.9691
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 63/100
# Train Loss: 0.0917, Train Acc: 0.9715, Train Recall: 0.9651, Train F1: 0.9658
# Val Loss: 0.0835, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 64/100
# Train Loss: 0.0867, Train Acc: 0.9733, Train Recall: 0.9666, Train F1: 0.9681
# Val Loss: 0.0830, Val Acc: 0.9744, Val Recall: 0.9712, Val F1: 0.9701
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 65/100
# Train Loss: 0.0912, Train Acc: 0.9735, Train Recall: 0.9680, Train F1: 0.9682
# Val Loss: 0.0833, Val Acc: 0.9740, Val Recall: 0.9702, Val F1: 0.9695
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 66/100
# Train Loss: 0.0900, Train Acc: 0.9710, Train Recall: 0.9642, Train F1: 0.9648
# Val Loss: 0.0837, Val Acc: 0.9749, Val Recall: 0.9705, Val F1: 0.9703
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 67/100
# Train Loss: 0.0923, Train Acc: 0.9704, Train Recall: 0.9635, Train F1: 0.9643
# Val Loss: 0.0846, Val Acc: 0.9740, Val Recall: 0.9703, Val F1: 0.9696
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 68/100
# Train Loss: 0.0884, Train Acc: 0.9723, Train Recall: 0.9653, Train F1: 0.9663
# Val Loss: 0.0829, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 69/100
# Train Loss: 0.0948, Train Acc: 0.9699, Train Recall: 0.9622, Train F1: 0.9627
# Val Loss: 0.0876, Val Acc: 0.9749, Val Recall: 0.9706, Val F1: 0.9702
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 70/100
# Train Loss: 0.0900, Train Acc: 0.9722, Train Recall: 0.9656, Train F1: 0.9657
# Val Loss: 0.0853, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9700
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 71/100
# Train Loss: 0.0899, Train Acc: 0.9709, Train Recall: 0.9631, Train F1: 0.9639
# Val Loss: 0.0848, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9700
# Learning Rate: 2.19e-06
# --------------------------------------------------
# Epoch 72/100
# Train Loss: 0.0924, Train Acc: 0.9702, Train Recall: 0.9626, Train F1: 0.9635
# Val Loss: 0.0858, Val Acc: 0.9744, Val Recall: 0.9706, Val F1: 0.9701
# Learning Rate: 6.56e-07
# --------------------------------------------------
# Epoch 73/100
# Train Loss: 0.0906, Train Acc: 0.9720, Train Recall: 0.9657, Train F1: 0.9658
# Val Loss: 0.0827, Val Acc: 0.9744, Val Recall: 0.9704, Val F1: 0.9699
# Learning Rate: 6.56e-07
# --------------------------------------------------
# Epoch 74/100
# Train Loss: 0.0918, Train Acc: 0.9709, Train Recall: 0.9637, Train F1: 0.9653
# Val Loss: 0.0848, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 6.56e-07
# --------------------------------------------------
# Epoch 75/100
# Train Loss: 0.0929, Train Acc: 0.9713, Train Recall: 0.9649, Train F1: 0.9653
# Val Loss: 0.0858, Val Acc: 0.9736, Val Recall: 0.9695, Val F1: 0.9687
# Learning Rate: 6.56e-07
# --------------------------------------------------
# Epoch 76/100
# Train Loss: 0.0938, Train Acc: 0.9696, Train Recall: 0.9619, Train F1: 0.9637
# Val Loss: 0.0839, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 6.56e-07
# --------------------------------------------------
# Epoch 77/100
# Train Loss: 0.0938, Train Acc: 0.9705, Train Recall: 0.9635, Train F1: 0.9646
# Val Loss: 0.0835, Val Acc: 0.9740, Val Recall: 0.9702, Val F1: 0.9695
# Learning Rate: 1.97e-07
# --------------------------------------------------
# Epoch 78/100
# Train Loss: 0.0946, Train Acc: 0.9714, Train Recall: 0.9645, Train F1: 0.9652
# Val Loss: 0.0901, Val Acc: 0.9740, Val Recall: 0.9702, Val F1: 0.9695
# Learning Rate: 1.97e-07
# --------------------------------------------------
# Epoch 79/100
# Train Loss: 0.0927, Train Acc: 0.9732, Train Recall: 0.9672, Train F1: 0.9681
# Val Loss: 0.0826, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 1.97e-07
# --------------------------------------------------
# Epoch 80/100
# Train Loss: 0.0917, Train Acc: 0.9716, Train Recall: 0.9647, Train F1: 0.9657
# Val Loss: 0.0829, Val Acc: 0.9749, Val Recall: 0.9715, Val F1: 0.9707
# Learning Rate: 1.97e-07
# --------------------------------------------------
# Epoch 81/100
# Train Loss: 0.0878, Train Acc: 0.9716, Train Recall: 0.9646, Train F1: 0.9652
# Val Loss: 0.0836, Val Acc: 0.9740, Val Recall: 0.9703, Val F1: 0.9693
# Learning Rate: 1.97e-07
# --------------------------------------------------
# Epoch 82/100
# Train Loss: 0.0874, Train Acc: 0.9714, Train Recall: 0.9643, Train F1: 0.9653
# Val Loss: 0.0837, Val Acc: 0.9740, Val Recall: 0.9702, Val F1: 0.9695
# Learning Rate: 1.97e-07
# --------------------------------------------------
# Epoch 83/100
# Train Loss: 0.0907, Train Acc: 0.9710, Train Recall: 0.9640, Train F1: 0.9651
# Val Loss: 0.0834, Val Acc: 0.9740, Val Recall: 0.9702, Val F1: 0.9695
# Learning Rate: 5.90e-08
# --------------------------------------------------
# Epoch 84/100
# Train Loss: 0.0892, Train Acc: 0.9723, Train Recall: 0.9660, Train F1: 0.9670
# Val Loss: 0.0839, Val Acc: 0.9749, Val Recall: 0.9714, Val F1: 0.9706
# Learning Rate: 5.90e-08
# --------------------------------------------------
# Epoch 85/100
# Train Loss: 0.0983, Train Acc: 0.9705, Train Recall: 0.9631, Train F1: 0.9639
# Val Loss: 0.0839, Val Acc: 0.9740, Val Recall: 0.9702, Val F1: 0.9695
# Learning Rate: 5.90e-08
# --------------------------------------------------
# Epoch 86/100
# Train Loss: 0.0986, Train Acc: 0.9678, Train Recall: 0.9596, Train F1: 0.9608
# Val Loss: 0.0873, Val Acc: 0.9740, Val Recall: 0.9701, Val F1: 0.9696
# Learning Rate: 5.90e-08
# --------------------------------------------------
# Epoch 87/100
# Train Loss: 0.0906, Train Acc: 0.9744, Train Recall: 0.9687, Train F1: 0.9689
# Val Loss: 0.0874, Val Acc: 0.9740, Val Recall: 0.9705, Val F1: 0.9695
# Learning Rate: 1.77e-08
# --------------------------------------------------
# Epoch 88/100
# Train Loss: 0.0969, Train Acc: 0.9692, Train Recall: 0.9619, Train F1: 0.9618
# Val Loss: 0.0832, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 1.77e-08
# --------------------------------------------------
# Epoch 89/100
# Train Loss: 0.0955, Train Acc: 0.9702, Train Recall: 0.9623, Train F1: 0.9634
# Val Loss: 0.0853, Val Acc: 0.9740, Val Recall: 0.9703, Val F1: 0.9696
# Learning Rate: 1.77e-08
# --------------------------------------------------
# Epoch 90/100
# Train Loss: 0.0914, Train Acc: 0.9728, Train Recall: 0.9662, Train F1: 0.9673
# Val Loss: 0.0832, Val Acc: 0.9749, Val Recall: 0.9714, Val F1: 0.9705
# Learning Rate: 1.77e-08
# --------------------------------------------------
# Epoch 91/100
# Train Loss: 0.0933, Train Acc: 0.9705, Train Recall: 0.9647, Train F1: 0.9655
# Val Loss: 0.0833, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 5.31e-09
# --------------------------------------------------
# Epoch 92/100
# Train Loss: 0.0941, Train Acc: 0.9708, Train Recall: 0.9632, Train F1: 0.9645
# Val Loss: 0.0845, Val Acc: 0.9732, Val Recall: 0.9690, Val F1: 0.9685
# Learning Rate: 5.31e-09
# --------------------------------------------------
# Epoch 93/100
# Train Loss: 0.0899, Train Acc: 0.9707, Train Recall: 0.9632, Train F1: 0.9637
# Val Loss: 0.0830, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 5.31e-09
# --------------------------------------------------
# Epoch 94/100
# Train Loss: 0.1034, Train Acc: 0.9675, Train Recall: 0.9588, Train F1: 0.9598
# Val Loss: 0.0843, Val Acc: 0.9736, Val Recall: 0.9695, Val F1: 0.9689
# Learning Rate: 5.31e-09
# --------------------------------------------------
# Epoch 95/100
# Train Loss: 0.0910, Train Acc: 0.9716, Train Recall: 0.9657, Train F1: 0.9662
# Val Loss: 0.0833, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 5.31e-09
# --------------------------------------------------
# Epoch 96/100
# Train Loss: 0.0891, Train Acc: 0.9726, Train Recall: 0.9659, Train F1: 0.9664
# Val Loss: 0.0833, Val Acc: 0.9749, Val Recall: 0.9714, Val F1: 0.9704
# Learning Rate: 5.31e-09
# --------------------------------------------------
# Epoch 97/100
# Train Loss: 0.0914, Train Acc: 0.9701, Train Recall: 0.9636, Train F1: 0.9637
# Val Loss: 0.0833, Val Acc: 0.9740, Val Recall: 0.9703, Val F1: 0.9695
# Learning Rate: 5.31e-09
# --------------------------------------------------
# Epoch 98/100
# Train Loss: 0.0910, Train Acc: 0.9727, Train Recall: 0.9667, Train F1: 0.9677
# Val Loss: 0.0856, Val Acc: 0.9736, Val Recall: 0.9695, Val F1: 0.9689
# Learning Rate: 5.31e-09
# --------------------------------------------------
# Epoch 99/100
# Train Loss: 0.0860, Train Acc: 0.9733, Train Recall: 0.9670, Train F1: 0.9679
# Val Loss: 0.0846, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 5.31e-09
# --------------------------------------------------
# Epoch 100/100
# Train Loss: 0.0895, Train Acc: 0.9713, Train Recall: 0.9638, Train F1: 0.9657
# Val Loss: 0.0897, Val Acc: 0.9744, Val Recall: 0.9708, Val F1: 0.9701
# Learning Rate: 5.31e-09
# Finished training!
# Time taken: 00:04:39.02

# %% [markdown]
# # Pokretanje na test skupu i komentar

# %% [markdown]
# **Iako je dodato još slojeva i arhitektura učinjena složenijom nego u prvoj verziji CNN-a, rezutati se nisu mnogo promenili, udaramo u zid od oko ~97% uspešnosti modela i mogli smo komotno da stanemo s treniranjem dosta ranije, čak i pre 100. epohe. Takođe, ovde deluje da model ima tendenciju da krene ka prilagođavanju, ali taman tu negde stane sa napretkom na trening skupu, tako da deluje da se nije preprilagodio (pisano pre puštanja provere na test skupu).**
#
# **Sada model daje zaista sjajne rezultate na test skupu ako gledamo njihovu sličnost sa rezultatima na trening, odnosno validacionom skupu. Vrednosti posmatranih metrika su maltene identične, a čak i nešto bolje. Ovo smo se i nadali da ćemo postići, tj. da će se CNN-ovi pokazati kao dobri generalizatori, a u ovom slučaju odlični, jer radi bolje na test skupu, nego na validacionom.**

# %%
model.eval()

all_preds_test = []
all_labels_test = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
with torch.no_grad():
    for inputs, labels in loaders['test']:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds_test.extend(preds.cpu().numpy())
        all_labels_test.extend(labels.cpu().numpy())

test_acc = accuracy_score(all_labels_test, all_preds_test)
test_prec = precision_score(all_labels_test, all_preds_test, average='macro')
test_recall = recall_score(all_labels_test, all_preds_test, average='macro')
test_f1 = f1_score(all_labels_test, all_preds_test, average='macro')

print(f"Test accuracy: {test_acc:.4f}")
print(f"Test precision: {test_prec:.4f}")
print(f"Test recall: {test_recall:.4f}")
print(f"Test F1 score: {test_f1:.4f}")

print("\nClassification report:")
print(classification_report(all_labels_test, all_preds_test, target_names=class_names))

cm = confusion_matrix(all_labels_test, all_preds_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Test accuracy: 0.9657
# Test precision: 0.9591
# Test recall: 0.9643
# Test F1 score: 0.9614
#
# Classification report:
#               precision    recall  f1-score   support
#
#     backhand       0.96      0.92      0.94       190
#     forehand       0.91      0.97      0.94       230
#        other       0.99      0.97      0.98       615
#        serve       0.98      1.00      0.99       159
#
#     accuracy                           0.97      1194
#    macro avg       0.96      0.96      0.96      1194
# weighted avg       0.97      0.97      0.97      1194

# %%
torch.save(model.state_dict(), '../../models/09_cnn_2_relabeled_data_100ep.pth')
torch.save(model, '../../models/09_cnn_2_relabeled_data_100ep_full.pth')
