# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix

import os
import shutil
from PIL import Image
import numpy as np
import seaborn as sns
import time

# %% [markdown]
# # Util funcs

# %% [markdown]
# Podaci su prečišćeni korišćenjem funkcije `handle_invalid_action_images(dataset)` dostupnoj i korišćenoj u svesci `../02_dataset_creation/07_handle_invalid_action_images.ipynb`, tako da u nastavku nisu neophodne dodatne provere u vezi formata slika, i sl.

# %%
def print_time_taken(start_time, end_time):
    elapsed_time = end_time - start_time
    hours, rem = divmod(elapsed_time, 3600)
    minutes, seconds = divmod(rem, 60)
    print(f"Time taken: {int(hours):02}:{int(minutes):02}:{seconds:05.2f}")

# %% [markdown]
# # CNN

# %%
class TennisStrokeCNNClassifier(nn.Module):
    def __init__(self, num_classes=4):
        
        super(TennisStrokeCNNClassifier, self).__init__()
        self.num_classes = num_classes
        
        self.pad1 = nn.ReplicationPad2d(1)
        
        self.conv1 = nn.Conv2d(3, 6, 3)
        self.bn1 = nn.BatchNorm2d(6)
        self.relu1 = nn.ReLU()
        
        self.conv2 = nn.Conv2d(6, 16, 3)
        self.bn2 = nn.BatchNorm2d(16)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.dropout1 = nn.Dropout(p=0.5)
        
        self.conv3 = nn.Conv2d(16, 32, 3)
        self.bn3 = nn.BatchNorm2d(32)
        self.relu3 = nn.ReLU()
        
        self.fc1 = nn.Linear(32 * 7 * 3, 128)
        self.relu4 = nn.ReLU()
        self.dropout2 = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(128, 64)
        self.relu5 = nn.ReLU()
        self.dropout3 = nn.Dropout(p=0.5)
        self.fc3 = nn.Linear(64, num_classes)
                
        
    def _num_flatten_features(self, x):
        num_features = 1
        for s in x.size()[1:]:  # Don't use batch size dim
            num_features *= s
        return num_features    
    
    
    def forward(self, x):
        x = self.pad1(x)
        x = self.relu1(self.bn1(self.conv1(x)))
        x = self.pool1(self.relu2(self.bn2(self.conv2(x))))
        x = self.dropout1(x)
        x = self.relu3(self.bn3(self.conv3(x)))
        
        x = x.view(-1, self._num_flatten_features(x))
        x = self.relu4(self.fc1(x))
        x = self.dropout2(x)
        x = self.relu5(self.fc2(x))
        x = self.fc3(x)
        
        x = F.log_softmax(x, dim=1)
        
        return x

# %%
def compute_dataset_stats(dataset_path, batch_size=64, random_state=42):
    full_dataset = datasets.ImageFolder(root=dataset_path, transform=transforms.ToTensor())    
    class_names = full_dataset.classes
    
    dataset_size = len(full_dataset)
    indices = list(range(dataset_size))
    
    # Dataset loading consisent with the rest of the project, using the same random_state and split sizes
    train_val_indices, test_indices = train_test_split(indices, test_size=test_size, stratify=full_dataset.targets, random_state=random_state)
    train_indices, val_indices = train_test_split(train_val_indices, test_size=val_size / (1 - test_size),
                                                  stratify=np.array(full_dataset.targets)[train_val_indices], 
                                                  random_state=random_state)
    
    train_set = Subset(full_dataset, train_indices)
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=8)
    
    mean = torch.zeros(3)
    std = torch.zeros(3)
    n_samples = 0
    
    for images, _ in train_loader:
        batch_samples = images.size(0)
        images = images.view(batch_samples, images.size(1), -1)
        mean += images.mean(2).sum(0)
        std += images.std(2).sum(0)
        n_samples += batch_samples
    
    mean /= n_samples
    std /= n_samples
    
    mean = mean.tolist()
    std = std.tolist()
    
    return mean, std

def set_random_state(seed):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

def train_net(num_epochs, dataset_path, num_classes=4, batch_size=32, lr=0.001,
              val_size=0.2, test_size=0.1, random_state=42, patience=3, factor=0.5):
    
    set_random_state(random_state)
    
    print('Calculating mean and std for normalization...')
    mean, std = compute_dataset_stats(dataset_path)
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=mean, std=std),
    ])
    
    full_dataset = datasets.ImageFolder(root=dataset_path, transform=transform)
    class_names = full_dataset.classes
    
    dataset_size = len(full_dataset)
    indices = list(range(dataset_size))
    
    # Dataset loading consisent with the rest of the project, using the same random_state and split sizes
    train_val_indices, test_indices = train_test_split(indices, test_size=test_size, stratify=full_dataset.targets, random_state=random_state)
    train_indices, val_indices = train_test_split(train_val_indices, test_size=val_size / (1 - test_size),
                                                  stratify=np.array(full_dataset.targets)[train_val_indices], 
                                                  random_state=random_state)
    
    train_set = Subset(full_dataset, train_indices)
    val_set = Subset(full_dataset, val_indices)
    test_set = Subset(full_dataset, test_indices)

    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=8)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=True, num_workers=8)
    test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=True, num_workers=8)
    
    model = TennisStrokeCNNClassifier(num_classes)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    # update lr when the conditions are met
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', 
                                                           factor=factor, patience=patience)

    # track all these changes during training
    train_accs, val_accs, train_losses, val_losses = [], [], [], []
    train_recalls, val_recalls, train_f1s, val_f1s = [], [], [], []
    learning_rates = []
    
    print('Training process initialized.')
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        all_preds_train = []
        all_labels_train = []
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            # zero the parameter gradients!
            optimizer.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            _, preds = torch.max(outputs, 1)
            all_preds_train.extend(preds.cpu().numpy())
            all_labels_train.extend(labels.cpu().numpy())
            
        train_loss = running_loss / len(train_loader)
        train_acc = accuracy_score(all_labels_train, all_preds_train)
        train_recall = recall_score(all_labels_train, all_preds_train, average='macro')
        train_f1 = f1_score(all_labels_train, all_preds_train, average='macro')
        
        train_losses.append(train_loss)
        train_accs.append(train_acc)
        train_recalls.append(train_recall)
        train_f1s.append(train_f1)
        
        model.eval()
        running_val_loss = 0.0
        all_preds_val = []
        all_labels_val = []
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                
                running_val_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                all_preds_val.extend(preds.cpu().numpy())
                all_labels_val.extend(labels.cpu().numpy())
        
        val_loss = running_val_loss / len(val_loader)
        val_acc = accuracy_score(all_labels_val, all_preds_val)
        val_recall = recall_score(all_labels_val, all_preds_val, average='macro')
        val_f1 = f1_score(all_labels_val, all_preds_val, average='macro')
        
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        val_recalls.append(val_recall)
        val_f1s.append(val_f1)

        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]['lr']
        learning_rates.append(scheduler.get_last_lr())
        
        print('-'*50)
        print(f'Epoch {epoch+1}/{num_epochs}')
        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, '
              f'Train Recall: {train_recall:.4f}, Train F1: {train_f1:.4f}')
        print(f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}, '
              f'Val Recall: {val_recall:.4f}, Val F1: {val_f1:.4f}')
        print(f'Learning Rate: {current_lr:.2e}')
        
    print('Finished training!')
    
    plt.figure(figsize=(15, 12))
    
    plt.subplot(3, 2, 1)
    plt.plot(range(1, num_epochs+1), train_losses, label="Train Loss")
    plt.plot(range(1, num_epochs+1), val_losses, label="Val Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(3, 2, 2)
    plt.plot(range(1, num_epochs+1), train_accs, label="Train Acc")
    plt.plot(range(1, num_epochs+1), val_accs, label="Val Acc")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(3, 2, 3)
    plt.plot(range(1, num_epochs+1), train_recalls, label="Train Recall")
    plt.plot(range(1, num_epochs+1), val_recalls, label="Val Recall")
    plt.xlabel("Epochs")
    plt.ylabel("Recall")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(3, 2, 4)
    plt.plot(range(1, num_epochs+1), train_f1s, label="Train F1")
    plt.plot(range(1, num_epochs+1), val_f1s, label="Val F1")
    plt.xlabel("Epochs")
    plt.ylabel("F1 Score")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(3, 2, 5)
    plt.plot(range(1, num_epochs+1), learning_rates, label="Learning Rate")
    plt.xlabel("Epochs")
    plt.ylabel("Learning Rate")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

    loaders = {
        'train': train_loader,
        'val': val_loader,
        'test': test_loader
    }
    
    return model, loaders, class_names

# %% [markdown]
# **Na dnu sveske je odrađena analiza za testni skup podataka.**
#
# *Iako je malo duža sveska zbog 100 epoha, ostavljeno je u celosti da bi mogao lepo da se isprati tok treniranja.*

# %%
start = time.time()

dataset_path = '../../data/datasets/action_images_dataset_v1.0'

num_epochs = 100
num_classes = 4
batch_size = 32
learning_rate = 0.001
val_size = 0.2
test_size = 0.1
seed = 42

model, loaders, class_names = train_net(
    num_epochs=num_epochs, 
    dataset_path=dataset_path, 
    num_classes=num_classes, 
    batch_size=batch_size, 
    lr=learning_rate,
    val_size=val_size,
    test_size=test_size,
    random_state=seed
)

end = time.time()
print_time_taken(start, end)
# Out:
# Calculating mean and std for normalization...
# /root/.local/share/virtualenvs/app-4PlAip0Q/lib/python3.8/site-packages/torch/cuda/__init__.py:128: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11020). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Training process initialized.
# --------------------------------------------------
# Epoch 1/100
# Train Loss: 0.7788, Train Acc: 0.6758, Train Recall: 0.5485, Train F1: 0.5738
# Val Loss: 0.4691, Val Acc: 0.8185, Val Recall: 0.7561, Val F1: 0.7599
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 2/100
# Train Loss: 0.5006, Train Acc: 0.8097, Train Recall: 0.7538, Train F1: 0.7571
# Val Loss: 0.3129, Val Acc: 0.8806, Val Recall: 0.8379, Val F1: 0.8444
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 3/100
# Train Loss: 0.4134, Train Acc: 0.8490, Train Recall: 0.8042, Train F1: 0.8087
# Val Loss: 0.2644, Val Acc: 0.8956, Val Recall: 0.8669, Val F1: 0.8630
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 4/100
# Train Loss: 0.3554, Train Acc: 0.8710, Train Recall: 0.8359, Train F1: 0.8394
# Val Loss: 0.2307, Val Acc: 0.9057, Val Recall: 0.8787, Val F1: 0.8792
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 5/100
# Train Loss: 0.3307, Train Acc: 0.8812, Train Recall: 0.8468, Train F1: 0.8504
# Val Loss: 0.2217, Val Acc: 0.9166, Val Recall: 0.8926, Val F1: 0.8922
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 6/100
# Train Loss: 0.2946, Train Acc: 0.8964, Train Recall: 0.8675, Train F1: 0.8703
# Val Loss: 0.2046, Val Acc: 0.9262, Val Recall: 0.9045, Val F1: 0.9070
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 7/100
# Train Loss: 0.2854, Train Acc: 0.9006, Train Recall: 0.8726, Train F1: 0.8753
# Val Loss: 0.2059, Val Acc: 0.9237, Val Recall: 0.9027, Val F1: 0.9044
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 8/100
# Train Loss: 0.2696, Train Acc: 0.9056, Train Recall: 0.8799, Train F1: 0.8825
# Val Loss: 0.1799, Val Acc: 0.9350, Val Recall: 0.9162, Val F1: 0.9193
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 9/100
# Train Loss: 0.2656, Train Acc: 0.9070, Train Recall: 0.8827, Train F1: 0.8850
# Val Loss: 0.1676, Val Acc: 0.9405, Val Recall: 0.9233, Val F1: 0.9252
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 10/100
# Train Loss: 0.2419, Train Acc: 0.9162, Train Recall: 0.8936, Train F1: 0.8963
# Val Loss: 0.1672, Val Acc: 0.9396, Val Recall: 0.9250, Val F1: 0.9230
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 11/100
# Train Loss: 0.2357, Train Acc: 0.9189, Train Recall: 0.8965, Train F1: 0.8989
# Val Loss: 0.1764, Val Acc: 0.9388, Val Recall: 0.9236, Val F1: 0.9250
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 12/100
# Train Loss: 0.2321, Train Acc: 0.9201, Train Recall: 0.8998, Train F1: 0.9017
# Val Loss: 0.1632, Val Acc: 0.9417, Val Recall: 0.9248, Val F1: 0.9275
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 13/100
# Train Loss: 0.2199, Train Acc: 0.9237, Train Recall: 0.9047, Train F1: 0.9063
# Val Loss: 0.1542, Val Acc: 0.9510, Val Recall: 0.9378, Val F1: 0.9398
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 14/100
# Train Loss: 0.2118, Train Acc: 0.9252, Train Recall: 0.9041, Train F1: 0.9059
# Val Loss: 0.1760, Val Acc: 0.9338, Val Recall: 0.9140, Val F1: 0.9156
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 15/100
# Train Loss: 0.2131, Train Acc: 0.9246, Train Recall: 0.9052, Train F1: 0.9069
# Val Loss: 0.1459, Val Acc: 0.9480, Val Recall: 0.9334, Val F1: 0.9349
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 16/100
# Train Loss: 0.1919, Train Acc: 0.9325, Train Recall: 0.9136, Train F1: 0.9160
# Val Loss: 0.1432, Val Acc: 0.9526, Val Recall: 0.9384, Val F1: 0.9411
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 17/100
# Train Loss: 0.2016, Train Acc: 0.9298, Train Recall: 0.9101, Train F1: 0.9126
# Val Loss: 0.1435, Val Acc: 0.9489, Val Recall: 0.9322, Val F1: 0.9361
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 18/100
# Train Loss: 0.1969, Train Acc: 0.9319, Train Recall: 0.9137, Train F1: 0.9160
# Val Loss: 0.1456, Val Acc: 0.9531, Val Recall: 0.9404, Val F1: 0.9419
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 19/100
# Train Loss: 0.1884, Train Acc: 0.9337, Train Recall: 0.9165, Train F1: 0.9184
# Val Loss: 0.1457, Val Acc: 0.9472, Val Recall: 0.9307, Val F1: 0.9338
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 20/100
# Train Loss: 0.1723, Train Acc: 0.9398, Train Recall: 0.9249, Train F1: 0.9270
# Val Loss: 0.1330, Val Acc: 0.9522, Val Recall: 0.9389, Val F1: 0.9403
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 21/100
# Train Loss: 0.1726, Train Acc: 0.9374, Train Recall: 0.9206, Train F1: 0.9224
# Val Loss: 0.1354, Val Acc: 0.9547, Val Recall: 0.9401, Val F1: 0.9448
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 22/100
# Train Loss: 0.1643, Train Acc: 0.9438, Train Recall: 0.9293, Train F1: 0.9310
# Val Loss: 0.1319, Val Acc: 0.9547, Val Recall: 0.9443, Val F1: 0.9439
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 23/100
# Train Loss: 0.1699, Train Acc: 0.9413, Train Recall: 0.9243, Train F1: 0.9268
# Val Loss: 0.1244, Val Acc: 0.9564, Val Recall: 0.9477, Val F1: 0.9468
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 24/100
# Train Loss: 0.1651, Train Acc: 0.9442, Train Recall: 0.9292, Train F1: 0.9316
# Val Loss: 0.1288, Val Acc: 0.9556, Val Recall: 0.9452, Val F1: 0.9461
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 25/100
# Train Loss: 0.1541, Train Acc: 0.9476, Train Recall: 0.9330, Train F1: 0.9348
# Val Loss: 0.1309, Val Acc: 0.9552, Val Recall: 0.9428, Val F1: 0.9436
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 26/100
# Train Loss: 0.1536, Train Acc: 0.9486, Train Recall: 0.9354, Train F1: 0.9367
# Val Loss: 0.1320, Val Acc: 0.9581, Val Recall: 0.9475, Val F1: 0.9490
# Learning Rate: 1.00e-03
# --------------------------------------------------
# Epoch 27/100
# Train Loss: 0.1617, Train Acc: 0.9432, Train Recall: 0.9294, Train F1: 0.9308
# Val Loss: 0.1335, Val Acc: 0.9543, Val Recall: 0.9411, Val F1: 0.9461
# Learning Rate: 5.00e-04
# --------------------------------------------------
# Epoch 28/100
# Train Loss: 0.1329, Train Acc: 0.9549, Train Recall: 0.9425, Train F1: 0.9445
# Val Loss: 0.1219, Val Acc: 0.9593, Val Recall: 0.9506, Val F1: 0.9505
# Learning Rate: 5.00e-04
# --------------------------------------------------
# Epoch 29/100
# Train Loss: 0.1207, Train Acc: 0.9602, Train Recall: 0.9507, Train F1: 0.9521
# Val Loss: 0.1119, Val Acc: 0.9627, Val Recall: 0.9517, Val F1: 0.9555
# Learning Rate: 5.00e-04
# --------------------------------------------------
# Epoch 30/100
# Train Loss: 0.1150, Train Acc: 0.9602, Train Recall: 0.9510, Train F1: 0.9520
# Val Loss: 0.1136, Val Acc: 0.9635, Val Recall: 0.9539, Val F1: 0.9547
# Learning Rate: 5.00e-04
# --------------------------------------------------
# Epoch 31/100
# Train Loss: 0.1224, Train Acc: 0.9598, Train Recall: 0.9488, Train F1: 0.9504
# Val Loss: 0.1156, Val Acc: 0.9652, Val Recall: 0.9555, Val F1: 0.9587
# Learning Rate: 5.00e-04
# --------------------------------------------------
# Epoch 32/100
# Train Loss: 0.1122, Train Acc: 0.9624, Train Recall: 0.9527, Train F1: 0.9535
# Val Loss: 0.1149, Val Acc: 0.9656, Val Recall: 0.9585, Val F1: 0.9580
# Learning Rate: 5.00e-04
# --------------------------------------------------
# Epoch 33/100
# Train Loss: 0.1205, Train Acc: 0.9592, Train Recall: 0.9498, Train F1: 0.9503
# Val Loss: 0.1032, Val Acc: 0.9661, Val Recall: 0.9568, Val F1: 0.9586
# Learning Rate: 5.00e-04
# --------------------------------------------------
# Epoch 34/100
# Train Loss: 0.1152, Train Acc: 0.9630, Train Recall: 0.9540, Train F1: 0.9550
# Val Loss: 0.1127, Val Acc: 0.9673, Val Recall: 0.9594, Val F1: 0.9627
# Learning Rate: 5.00e-04
# --------------------------------------------------
# Epoch 35/100
# Train Loss: 0.1174, Train Acc: 0.9626, Train Recall: 0.9538, Train F1: 0.9543
# Val Loss: 0.1043, Val Acc: 0.9665, Val Recall: 0.9570, Val F1: 0.9586
# Learning Rate: 5.00e-04
# --------------------------------------------------
# Epoch 36/100
# Train Loss: 0.1145, Train Acc: 0.9622, Train Recall: 0.9526, Train F1: 0.9540
# Val Loss: 0.1095, Val Acc: 0.9627, Val Recall: 0.9526, Val F1: 0.9543
# Learning Rate: 5.00e-04
# --------------------------------------------------
# Epoch 37/100
# Train Loss: 0.1037, Train Acc: 0.9658, Train Recall: 0.9569, Train F1: 0.9576
# Val Loss: 0.1154, Val Acc: 0.9627, Val Recall: 0.9523, Val F1: 0.9548
# Learning Rate: 2.50e-04
# --------------------------------------------------
# Epoch 38/100
# Train Loss: 0.0958, Train Acc: 0.9660, Train Recall: 0.9570, Train F1: 0.9576
# Val Loss: 0.1123, Val Acc: 0.9644, Val Recall: 0.9543, Val F1: 0.9573
# Learning Rate: 2.50e-04
# --------------------------------------------------
# Epoch 39/100
# Train Loss: 0.0985, Train Acc: 0.9670, Train Recall: 0.9588, Train F1: 0.9603
# Val Loss: 0.1065, Val Acc: 0.9702, Val Recall: 0.9626, Val F1: 0.9642
# Learning Rate: 2.50e-04
# --------------------------------------------------
# Epoch 40/100
# Train Loss: 0.0937, Train Acc: 0.9680, Train Recall: 0.9596, Train F1: 0.9609
# Val Loss: 0.1050, Val Acc: 0.9711, Val Recall: 0.9648, Val F1: 0.9659
# Learning Rate: 2.50e-04
# --------------------------------------------------
# Epoch 41/100
# Train Loss: 0.0944, Train Acc: 0.9677, Train Recall: 0.9583, Train F1: 0.9597
# Val Loss: 0.1020, Val Acc: 0.9719, Val Recall: 0.9655, Val F1: 0.9665
# Learning Rate: 2.50e-04
# --------------------------------------------------
# Epoch 42/100
# Train Loss: 0.0964, Train Acc: 0.9698, Train Recall: 0.9622, Train F1: 0.9635
# Val Loss: 0.1027, Val Acc: 0.9690, Val Recall: 0.9620, Val F1: 0.9638
# Learning Rate: 2.50e-04
# --------------------------------------------------
# Epoch 43/100
# Train Loss: 0.0994, Train Acc: 0.9665, Train Recall: 0.9586, Train F1: 0.9596
# Val Loss: 0.1014, Val Acc: 0.9707, Val Recall: 0.9640, Val F1: 0.9661
# Learning Rate: 2.50e-04
# --------------------------------------------------
# Epoch 44/100
# Train Loss: 0.0914, Train Acc: 0.9701, Train Recall: 0.9622, Train F1: 0.9637
# Val Loss: 0.0979, Val Acc: 0.9723, Val Recall: 0.9659, Val F1: 0.9672
# Learning Rate: 2.50e-04
# --------------------------------------------------
# Epoch 45/100
# Train Loss: 0.0860, Train Acc: 0.9690, Train Recall: 0.9610, Train F1: 0.9617
# Val Loss: 0.1051, Val Acc: 0.9681, Val Recall: 0.9592, Val F1: 0.9625
# Learning Rate: 2.50e-04
# --------------------------------------------------
# Epoch 46/100
# Train Loss: 0.0927, Train Acc: 0.9702, Train Recall: 0.9626, Train F1: 0.9634
# Val Loss: 0.1044, Val Acc: 0.9694, Val Recall: 0.9620, Val F1: 0.9638
# Learning Rate: 2.50e-04
# --------------------------------------------------
# Epoch 47/100
# Train Loss: 0.0844, Train Acc: 0.9707, Train Recall: 0.9633, Train F1: 0.9641
# Val Loss: 0.1081, Val Acc: 0.9686, Val Recall: 0.9598, Val F1: 0.9626
# Learning Rate: 2.50e-04
# --------------------------------------------------
# Epoch 48/100
# Train Loss: 0.0921, Train Acc: 0.9695, Train Recall: 0.9618, Train F1: 0.9628
# Val Loss: 0.1056, Val Acc: 0.9673, Val Recall: 0.9595, Val F1: 0.9620
# Learning Rate: 1.25e-04
# --------------------------------------------------
# Epoch 49/100
# Train Loss: 0.0843, Train Acc: 0.9707, Train Recall: 0.9621, Train F1: 0.9633
# Val Loss: 0.1018, Val Acc: 0.9702, Val Recall: 0.9626, Val F1: 0.9649
# Learning Rate: 1.25e-04
# --------------------------------------------------
# Epoch 50/100
# Train Loss: 0.0844, Train Acc: 0.9721, Train Recall: 0.9648, Train F1: 0.9662
# Val Loss: 0.1016, Val Acc: 0.9702, Val Recall: 0.9629, Val F1: 0.9650
# Learning Rate: 1.25e-04
# --------------------------------------------------
# Epoch 51/100
# Train Loss: 0.0852, Train Acc: 0.9701, Train Recall: 0.9624, Train F1: 0.9628
# Val Loss: 0.1021, Val Acc: 0.9719, Val Recall: 0.9653, Val F1: 0.9670
# Learning Rate: 1.25e-04
# --------------------------------------------------
# Epoch 52/100
# Train Loss: 0.0847, Train Acc: 0.9713, Train Recall: 0.9644, Train F1: 0.9652
# Val Loss: 0.1017, Val Acc: 0.9715, Val Recall: 0.9655, Val F1: 0.9669
# Learning Rate: 6.25e-05
# --------------------------------------------------
# Epoch 53/100
# Train Loss: 0.0770, Train Acc: 0.9729, Train Recall: 0.9664, Train F1: 0.9668
# Val Loss: 0.1031, Val Acc: 0.9707, Val Recall: 0.9640, Val F1: 0.9661
# Learning Rate: 6.25e-05
# --------------------------------------------------
# Epoch 54/100
# Train Loss: 0.0776, Train Acc: 0.9733, Train Recall: 0.9671, Train F1: 0.9677
# Val Loss: 0.1015, Val Acc: 0.9723, Val Recall: 0.9663, Val F1: 0.9680
# Learning Rate: 6.25e-05
# --------------------------------------------------
# Epoch 55/100
# Train Loss: 0.0772, Train Acc: 0.9739, Train Recall: 0.9672, Train F1: 0.9680
# Val Loss: 0.1024, Val Acc: 0.9711, Val Recall: 0.9641, Val F1: 0.9666
# Learning Rate: 6.25e-05
# --------------------------------------------------
# Epoch 56/100
# Train Loss: 0.0795, Train Acc: 0.9732, Train Recall: 0.9666, Train F1: 0.9673
# Val Loss: 0.1036, Val Acc: 0.9702, Val Recall: 0.9636, Val F1: 0.9661
# Learning Rate: 3.13e-05
# --------------------------------------------------
# Epoch 57/100
# Train Loss: 0.0697, Train Acc: 0.9763, Train Recall: 0.9702, Train F1: 0.9714
# Val Loss: 0.1039, Val Acc: 0.9702, Val Recall: 0.9633, Val F1: 0.9649
# Learning Rate: 3.13e-05
# --------------------------------------------------
# Epoch 58/100
# Train Loss: 0.0771, Train Acc: 0.9751, Train Recall: 0.9691, Train F1: 0.9694
# Val Loss: 0.1025, Val Acc: 0.9715, Val Recall: 0.9648, Val F1: 0.9666
# Learning Rate: 3.13e-05
# --------------------------------------------------
# Epoch 59/100
# Train Loss: 0.0794, Train Acc: 0.9734, Train Recall: 0.9677, Train F1: 0.9683
# Val Loss: 0.1034, Val Acc: 0.9707, Val Recall: 0.9636, Val F1: 0.9659
# Learning Rate: 3.13e-05
# --------------------------------------------------
# Epoch 60/100
# Train Loss: 0.0720, Train Acc: 0.9755, Train Recall: 0.9689, Train F1: 0.9698
# Val Loss: 0.1017, Val Acc: 0.9711, Val Recall: 0.9648, Val F1: 0.9659
# Learning Rate: 1.56e-05
# --------------------------------------------------
# Epoch 61/100
# Train Loss: 0.0805, Train Acc: 0.9709, Train Recall: 0.9646, Train F1: 0.9647
# Val Loss: 0.1018, Val Acc: 0.9715, Val Recall: 0.9648, Val F1: 0.9669
# Learning Rate: 1.56e-05
# --------------------------------------------------
# Epoch 62/100
# Train Loss: 0.0812, Train Acc: 0.9727, Train Recall: 0.9660, Train F1: 0.9673
# Val Loss: 0.1042, Val Acc: 0.9711, Val Recall: 0.9646, Val F1: 0.9664
# Learning Rate: 1.56e-05
# --------------------------------------------------
# Epoch 63/100
# Train Loss: 0.0731, Train Acc: 0.9747, Train Recall: 0.9700, Train F1: 0.9696
# Val Loss: 0.1018, Val Acc: 0.9715, Val Recall: 0.9653, Val F1: 0.9666
# Learning Rate: 1.56e-05
# --------------------------------------------------
# Epoch 64/100
# Train Loss: 0.0792, Train Acc: 0.9735, Train Recall: 0.9665, Train F1: 0.9670
# Val Loss: 0.1003, Val Acc: 0.9719, Val Recall: 0.9655, Val F1: 0.9670
# Learning Rate: 7.81e-06
# --------------------------------------------------
# Epoch 65/100
# Train Loss: 0.0768, Train Acc: 0.9761, Train Recall: 0.9691, Train F1: 0.9702
# Val Loss: 0.1007, Val Acc: 0.9711, Val Recall: 0.9643, Val F1: 0.9662
# Learning Rate: 7.81e-06
# --------------------------------------------------
# Epoch 66/100
# Train Loss: 0.0796, Train Acc: 0.9721, Train Recall: 0.9653, Train F1: 0.9660
# Val Loss: 0.1018, Val Acc: 0.9711, Val Recall: 0.9643, Val F1: 0.9662
# Learning Rate: 7.81e-06
# --------------------------------------------------
# Epoch 67/100
# Train Loss: 0.0763, Train Acc: 0.9749, Train Recall: 0.9686, Train F1: 0.9687
# Val Loss: 0.1020, Val Acc: 0.9702, Val Recall: 0.9630, Val F1: 0.9654
# Learning Rate: 7.81e-06
# --------------------------------------------------
# Epoch 68/100
# Train Loss: 0.0774, Train Acc: 0.9749, Train Recall: 0.9685, Train F1: 0.9686
# Val Loss: 0.1011, Val Acc: 0.9698, Val Recall: 0.9628, Val F1: 0.9650
# Learning Rate: 3.91e-06
# --------------------------------------------------
# Epoch 69/100
# Train Loss: 0.0762, Train Acc: 0.9740, Train Recall: 0.9677, Train F1: 0.9679
# Val Loss: 0.1021, Val Acc: 0.9707, Val Recall: 0.9640, Val F1: 0.9659
# Learning Rate: 3.91e-06
# --------------------------------------------------
# Epoch 70/100
# Train Loss: 0.0722, Train Acc: 0.9759, Train Recall: 0.9695, Train F1: 0.9702
# Val Loss: 0.1008, Val Acc: 0.9707, Val Recall: 0.9635, Val F1: 0.9660
# Learning Rate: 3.91e-06
# --------------------------------------------------
# Epoch 71/100
# Train Loss: 0.0727, Train Acc: 0.9768, Train Recall: 0.9705, Train F1: 0.9713
# Val Loss: 0.1033, Val Acc: 0.9694, Val Recall: 0.9621, Val F1: 0.9643
# Learning Rate: 3.91e-06
# --------------------------------------------------
# Epoch 72/100
# Train Loss: 0.0735, Train Acc: 0.9758, Train Recall: 0.9695, Train F1: 0.9701
# Val Loss: 0.1003, Val Acc: 0.9711, Val Recall: 0.9646, Val F1: 0.9665
# Learning Rate: 1.95e-06
# --------------------------------------------------
# Epoch 73/100
# Train Loss: 0.0759, Train Acc: 0.9746, Train Recall: 0.9686, Train F1: 0.9688
# Val Loss: 0.1027, Val Acc: 0.9711, Val Recall: 0.9637, Val F1: 0.9664
# Learning Rate: 1.95e-06
# --------------------------------------------------
# Epoch 74/100
# Train Loss: 0.0727, Train Acc: 0.9772, Train Recall: 0.9719, Train F1: 0.9725
# Val Loss: 0.1015, Val Acc: 0.9732, Val Recall: 0.9676, Val F1: 0.9687
# Learning Rate: 1.95e-06
# --------------------------------------------------
# Epoch 75/100
# Train Loss: 0.0765, Train Acc: 0.9728, Train Recall: 0.9667, Train F1: 0.9672
# Val Loss: 0.1014, Val Acc: 0.9702, Val Recall: 0.9634, Val F1: 0.9652
# Learning Rate: 1.95e-06
# --------------------------------------------------
# Epoch 76/100
# Train Loss: 0.0763, Train Acc: 0.9728, Train Recall: 0.9653, Train F1: 0.9660
# Val Loss: 0.0996, Val Acc: 0.9719, Val Recall: 0.9655, Val F1: 0.9672
# Learning Rate: 9.77e-07
# --------------------------------------------------
# Epoch 77/100
# Train Loss: 0.0746, Train Acc: 0.9744, Train Recall: 0.9683, Train F1: 0.9689
# Val Loss: 0.1015, Val Acc: 0.9698, Val Recall: 0.9628, Val F1: 0.9649
# Learning Rate: 9.77e-07
# --------------------------------------------------
# Epoch 78/100
# Train Loss: 0.0729, Train Acc: 0.9750, Train Recall: 0.9681, Train F1: 0.9692
# Val Loss: 0.1020, Val Acc: 0.9715, Val Recall: 0.9652, Val F1: 0.9670
# Learning Rate: 9.77e-07
# --------------------------------------------------
# Epoch 79/100
# Train Loss: 0.0759, Train Acc: 0.9743, Train Recall: 0.9674, Train F1: 0.9682
# Val Loss: 0.1020, Val Acc: 0.9707, Val Recall: 0.9635, Val F1: 0.9660
# Learning Rate: 9.77e-07
# --------------------------------------------------
# Epoch 80/100
# Train Loss: 0.0812, Train Acc: 0.9732, Train Recall: 0.9662, Train F1: 0.9666
# Val Loss: 0.1004, Val Acc: 0.9723, Val Recall: 0.9662, Val F1: 0.9674
# Learning Rate: 4.88e-07
# --------------------------------------------------
# Epoch 81/100
# Train Loss: 0.0741, Train Acc: 0.9743, Train Recall: 0.9677, Train F1: 0.9686
# Val Loss: 0.1012, Val Acc: 0.9707, Val Recall: 0.9641, Val F1: 0.9658
# Learning Rate: 4.88e-07
# --------------------------------------------------
# Epoch 82/100
# Train Loss: 0.0746, Train Acc: 0.9747, Train Recall: 0.9679, Train F1: 0.9688
# Val Loss: 0.1025, Val Acc: 0.9702, Val Recall: 0.9630, Val F1: 0.9654
# Learning Rate: 4.88e-07
# --------------------------------------------------
# Epoch 83/100
# Train Loss: 0.0701, Train Acc: 0.9766, Train Recall: 0.9708, Train F1: 0.9715
# Val Loss: 0.1007, Val Acc: 0.9719, Val Recall: 0.9660, Val F1: 0.9671
# Learning Rate: 4.88e-07
# --------------------------------------------------
# Epoch 84/100
# Train Loss: 0.0742, Train Acc: 0.9747, Train Recall: 0.9677, Train F1: 0.9689
# Val Loss: 0.1032, Val Acc: 0.9723, Val Recall: 0.9664, Val F1: 0.9674
# Learning Rate: 2.44e-07
# --------------------------------------------------
# Epoch 85/100
# Train Loss: 0.0723, Train Acc: 0.9768, Train Recall: 0.9708, Train F1: 0.9714
# Val Loss: 0.1021, Val Acc: 0.9711, Val Recall: 0.9648, Val F1: 0.9662
# Learning Rate: 2.44e-07
# --------------------------------------------------
# Epoch 86/100
# Train Loss: 0.0748, Train Acc: 0.9747, Train Recall: 0.9693, Train F1: 0.9692
# Val Loss: 0.1022, Val Acc: 0.9715, Val Recall: 0.9652, Val F1: 0.9667
# Learning Rate: 2.44e-07
# --------------------------------------------------
# Epoch 87/100
# Train Loss: 0.0751, Train Acc: 0.9739, Train Recall: 0.9678, Train F1: 0.9683
# Val Loss: 0.1009, Val Acc: 0.9715, Val Recall: 0.9653, Val F1: 0.9668
# Learning Rate: 2.44e-07
# --------------------------------------------------
# Epoch 88/100
# Train Loss: 0.0732, Train Acc: 0.9750, Train Recall: 0.9701, Train F1: 0.9705
# Val Loss: 0.1034, Val Acc: 0.9707, Val Recall: 0.9635, Val F1: 0.9659
# Learning Rate: 1.22e-07
# --------------------------------------------------
# Epoch 89/100
# Train Loss: 0.0770, Train Acc: 0.9743, Train Recall: 0.9685, Train F1: 0.9690
# Val Loss: 0.1007, Val Acc: 0.9711, Val Recall: 0.9646, Val F1: 0.9664
# Learning Rate: 1.22e-07
# --------------------------------------------------
# Epoch 90/100
# Train Loss: 0.0738, Train Acc: 0.9756, Train Recall: 0.9700, Train F1: 0.9703
# Val Loss: 0.1050, Val Acc: 0.9702, Val Recall: 0.9626, Val F1: 0.9652
# Learning Rate: 1.22e-07
# --------------------------------------------------
# Epoch 91/100
# Train Loss: 0.0741, Train Acc: 0.9750, Train Recall: 0.9694, Train F1: 0.9693
# Val Loss: 0.1032, Val Acc: 0.9715, Val Recall: 0.9648, Val F1: 0.9669
# Learning Rate: 1.22e-07
# --------------------------------------------------
# Epoch 92/100
# Train Loss: 0.0747, Train Acc: 0.9735, Train Recall: 0.9661, Train F1: 0.9672
# Val Loss: 0.1053, Val Acc: 0.9702, Val Recall: 0.9630, Val F1: 0.9653
# Learning Rate: 6.10e-08
# --------------------------------------------------
# Epoch 93/100
# Train Loss: 0.0784, Train Acc: 0.9735, Train Recall: 0.9669, Train F1: 0.9672
# Val Loss: 0.1008, Val Acc: 0.9715, Val Recall: 0.9653, Val F1: 0.9668
# Learning Rate: 6.10e-08
# --------------------------------------------------
# Epoch 94/100
# Train Loss: 0.0751, Train Acc: 0.9739, Train Recall: 0.9677, Train F1: 0.9680
# Val Loss: 0.1020, Val Acc: 0.9715, Val Recall: 0.9648, Val F1: 0.9668
# Learning Rate: 6.10e-08
# --------------------------------------------------
# Epoch 95/100
# Train Loss: 0.0725, Train Acc: 0.9747, Train Recall: 0.9680, Train F1: 0.9690
# Val Loss: 0.1012, Val Acc: 0.9711, Val Recall: 0.9642, Val F1: 0.9663
# Learning Rate: 6.10e-08
# --------------------------------------------------
# Epoch 96/100
# Train Loss: 0.0755, Train Acc: 0.9741, Train Recall: 0.9678, Train F1: 0.9685
# Val Loss: 0.1012, Val Acc: 0.9707, Val Recall: 0.9640, Val F1: 0.9659
# Learning Rate: 3.05e-08
# --------------------------------------------------
# Epoch 97/100
# Train Loss: 0.0744, Train Acc: 0.9759, Train Recall: 0.9700, Train F1: 0.9706
# Val Loss: 0.1012, Val Acc: 0.9707, Val Recall: 0.9638, Val F1: 0.9659
# Learning Rate: 3.05e-08
# --------------------------------------------------
# Epoch 98/100
# Train Loss: 0.0749, Train Acc: 0.9750, Train Recall: 0.9692, Train F1: 0.9692
# Val Loss: 0.1027, Val Acc: 0.9702, Val Recall: 0.9630, Val F1: 0.9653
# Learning Rate: 3.05e-08
# --------------------------------------------------
# Epoch 99/100
# Train Loss: 0.0756, Train Acc: 0.9735, Train Recall: 0.9665, Train F1: 0.9672
# Val Loss: 0.1014, Val Acc: 0.9707, Val Recall: 0.9635, Val F1: 0.9659
# Learning Rate: 3.05e-08
# --------------------------------------------------
# Epoch 100/100
# Train Loss: 0.0723, Train Acc: 0.9763, Train Recall: 0.9712, Train F1: 0.9711
# Val Loss: 0.1033, Val Acc: 0.9707, Val Recall: 0.9635, Val F1: 0.9659
# Learning Rate: 1.53e-08
# Finished training!
# Time taken: 00:05:22.80

# %% [markdown]
# # Pokretanje na test skupu i komentar

# %% [markdown]
# **Kao i u prethodnoj svesci gde je treniran CNN na "lošim" podacima, a i u onoj gde je trenirano 50 epoha, možemo primetiti da za razliku od ostalih modela CNN daje ozbiljno dobre rezultate na test skupu ako gledamo njihovu sličnost sa rezultatima na trening, odnosno validacionom skupu. Vrednosti posmatranih metrika su maltene identične. Ovo smo se i nadali da ćemo postići, tj. da će se CNN-ovi pokazati kao dobri generalizatori.**

# %%
model.eval()

all_preds_test = []
all_labels_test = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
with torch.no_grad():
    for inputs, labels in loaders['test']:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds_test.extend(preds.cpu().numpy())
        all_labels_test.extend(labels.cpu().numpy())

test_acc = accuracy_score(all_labels_test, all_preds_test)
test_prec = precision_score(all_labels_test, all_preds_test, average='macro')
test_recall = recall_score(all_labels_test, all_preds_test, average='macro')
test_f1 = f1_score(all_labels_test, all_preds_test, average='macro')

print(f"Test accuracy: {test_acc:.4f}")
print(f"Test precision: {test_prec:.4f}")
print(f"Test recall: {test_recall:.4f}")
print(f"Test F1 score: {test_f1:.4f}")

print("\nClassification report:")
print(classification_report(all_labels_test, all_preds_test, target_names=class_names))

cm = confusion_matrix(all_labels_test, all_preds_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Test accuracy: 0.9631
# Test precision: 0.9563
# Test recall: 0.9599
# Test F1 score: 0.9581
#
# Classification report:
#               precision    recall  f1-score   support
#
#     backhand       0.93      0.93      0.93       190
#     forehand       0.93      0.94      0.94       230
#        other       0.98      0.97      0.98       615
#        serve       0.99      1.00      0.99       159
#
#     accuracy                           0.96      1194
#    macro avg       0.96      0.96      0.96      1194
# weighted avg       0.96      0.96      0.96      1194

# %%
torch.save(model.state_dict(), '../../models/08_cnn_relabeled_data_100ep.pth')
torch.save(model, '../../models/08_cnn_relabeled_data_100ep_full.pth')
